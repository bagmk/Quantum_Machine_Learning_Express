# %%
from qiskit import *
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import IBMQ, Aer, execute,assemble,QuantumCircuit, aqua
from qiskit.visualization import plot_histogram, plot_bloch_vector, plot_bloch_multivector
from qiskit.quantum_info import Statevector
from qiskit.extensions import *
provider = IBMQ.load_account()

from qiskit.quantum_info import random_unitary

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import math
from math import pi, sqrt

from random import seed
from random import random
import cmath

from qiskit.circuit import Parameter

import numpy as np
import scipy.linalg as la
from qiskit.exceptions import QiskitError
from qiskit.quantum_info.states.densitymatrix import DensityMatrix, Statevector
from qiskit.quantum_info.states.utils import (partial_trace, shannon_entropy,_format_state, _funm_svd)
# Out:
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     816             log.debug("Retry: %s", url)
# --> 817             return self.urlopen(
#     818                 method,
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     816             log.debug("Retry: %s", url)
# --> 817             return self.urlopen(
#     818                 method,
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     816             log.debug("Retry: %s", url)
# --> 817             return self.urlopen(
#     818                 method,
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     816             log.debug("Retry: %s", url)
# --> 817             return self.urlopen(
#     818                 method,
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     816             log.debug("Retry: %s", url)
# --> 817             return self.urlopen(
#     818                 method,
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     806             try:
# --> 807                 retries = retries.increment(method, url, response=response, _pool=self)
#     808             except MaxRetryError:
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\api\session.py in increment(self, method, url, response, error, _pool, _stacktrace)
#      92                          method, url, status, error, data, headers)
# ---> 93         return super().increment(method=method, url=url, response=response,
#      94                                  error=error, _pool=_pool, _stacktrace=_stacktrace)
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#
# MaxRetryError: HTTPSConnectionPool(host='auth.quantum-computing.ibm.com', port=443): Max retries exceeded with url: /api/users/me (Caused by ResponseError('too many 500 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\api\session.py in request(self, method, url, bare, **kwargs)
#     272             self._log_request_info(url, method, kwargs)
# --> 273             response = super().request(method, final_url, headers=headers, **kwargs)
#     274             response.raise_for_status()
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506             if isinstance(e.reason, ResponseError):
# --> 507                 raise RetryError(e, request=request)
#     508
#
# RetryError: HTTPSConnectionPool(host='auth.quantum-computing.ibm.com', port=443): Max retries exceeded with url: /api/users/me (Caused by ResponseError('too many 500 error responses'))
#
# The above exception was the direct cause of the following exception:
#
# RequestsApiError                          Traceback (most recent call last)
# <ipython-input-3-2c90b4711a9a> in <module>
#       5 from qiskit.quantum_info import Statevector
#       6 from qiskit.extensions import *
# ----> 7 provider = IBMQ.load_account()
#       8
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py in load_account(self)
#     200             self.disable_account()
#     201
# --> 202         self._initialize_providers(credentials)
#     203
#     204         # Prevent edge case where no hubs are available.
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py in _initialize_providers(self, credentials)
#     461             credentials: Credentials for IBM Quantum Experience.
#     462         """
# --> 463         auth_client = AuthClient(credentials.token,
#     464                                  credentials.base_url,
#     465                                  **credentials.connection_parameters())
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\api\clients\auth.py in __init__(self, api_token, auth_url, **request_kwargs)
#      41
#      42         self.auth_api = Api(RetrySession(auth_url, **request_kwargs))
# ---> 43         self.base_api = self._init_service_clients(**request_kwargs)
#      44
#      45     def _init_service_clients(self, **request_kwargs: Any) -> Api:
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\api\clients\auth.py in _init_service_clients(self, **request_kwargs)
#      56         # Use the token for the next auth server requests.
#      57         self.auth_api.session.access_token = access_token
# ---> 58         self._service_urls = self.user_urls()
#      59
#      60         # Create the api server client, using the access token.
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\api\clients\auth.py in user_urls(self)
#     108                 * ``services`: The API URL for additional services.
#     109         """
# --> 110         response = self.auth_api.user_info()
#     111         return response['urls']
#     112
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\api\rest\root.py in user_info(self)
#     134         """
#     135         url = self.get_url('user_info')
# --> 136         response = self.session.get(url).json()
#     137
#     138         return response
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# ~\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\api\session.py in request(self, method, url, bare, **kwargs)
#     294                 self._modify_chained_exception_messages(ex)
#     295
# --> 296             raise RequestsApiError(message, status_code) from ex
#     297
#     298         return response
#
# RequestsApiError: "HTTPSConnectionPool(host='auth.quantum-computing.ibm.com', port=443): Max retries exceeded with url: /api/users/me (Caused by ResponseError('too many 500 error responses'))"

# %%
qr = QuantumRegister(2)
qc = QuantumCircuit(qr)


qargs = [0] if dims[0] > dims[1] else [1]
rho = partial_trace(state, qargs)
float(np.sqrt(2 * (1 - np.real(purity(rho)))))
