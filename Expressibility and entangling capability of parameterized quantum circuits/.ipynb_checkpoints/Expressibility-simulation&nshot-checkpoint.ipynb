# %% [markdown]
# # Understand the behavior of number of the shots and simulator
#
# Since the number of the shots from the simulator play role in the accuracy and the expressibilty, we want to further study the effect of the those parameters.
#
# In this document, we will only focus on the arbitary circuit since it should give identical result with the harr distribution.

# %%
from matplotlib import pyplot
from qiskit import *
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import IBMQ, Aer, execute,assemble,QuantumCircuit, aqua
from qiskit.visualization import plot_histogram, plot_bloch_vector, plot_bloch_multivector
from qiskit.quantum_info import Statevector
from qiskit.extensions import *
provider = IBMQ.load_account()

from qiskit.quantum_info import random_unitary
from qiskit.providers.aer import QasmSimulator, StatevectorSimulator, UnitarySimulator
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import math
from math import pi, sqrt

from scipy.special import rel_entr
from random import seed
from random import random
import cmath
# Out:
# C:\Users\Saesun Kim\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '
# ibmqfactory.load_account:WARNING:2021-03-21 00:35:02,909: Credentials are already in use. The existing account in the session will be replaced.

# %%
#Possible Bin
bins_list=[];
for i in range(76):
    bins_list.append((i)/75)
#Center of the Bean
bins_x=[]    
for i in range(75):
    bins_x.append(bins_list[1]+bins_list[i])
def P_harr(l,u,N):
    return (1-l)**(N-1)-(1-u)**(N-1)
#Harr historgram
P_harr_hist=[]
for i in range(75):
    P_harr_hist.append(P_harr(bins_list[i],bins_list[i+1],2))    
#Imaginary    
j=(-1)**(1/2)

# %% [markdown]
# ## Arbitary Unitary Qasm_simulator

# %%
backend = Aer.get_backend('qasm_simulator')
for x in range(1,20,1):
    print()
arr = []
for nsh in range(1,20,1):
    arr.append([])
    for lp in range(1,10,1):
        nshot=int(round(1000*(nsh)**1.5,0))
        nparam=1000*lp
        fidelity=[]    
        for x in range(nparam):
            qr = QuantumRegister(1)
            cr = ClassicalRegister(1)
            qc = QuantumCircuit(qr, cr)

            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )
            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )

            qc.measure(qr[0],cr[0])
            job = execute(qc, backend, shots=nshot)
            result = job.result()
            count =result.get_counts()

            if '0' in count and '1' in count:
                ratio=count['0']/nshot
            elif '0' in count and '1' not in count:
                ratio=count['0']/nshot
            else:
                ratio=0

            fidelity.append(ratio)   
            #Kullback Leibler divergence
        weights = np.ones_like(fidelity)/float(len(fidelity))            
        P_U_hist=np.histogram(fidelity, bins=bins_list, weights=weights, range=[0, 1])[0];
        #Kullback Leibler divergence
        print(nshot,'shots per simulation',nparam,'distribution size')
        arr[nsh-1].append(sum(rel_entr(P_U_hist, P_harr_hist)))
# Out:
# 1000 shots per simulation 1000 distribution size
# 1000 shots per simulation 2000 distribution size
# 1000 shots per simulation 3000 distribution size
# 1000 shots per simulation 4000 distribution size
# 1000 shots per simulation 5000 distribution size
# 1000 shots per simulation 6000 distribution size
# 1000 shots per simulation 7000 distribution size
# 1000 shots per simulation 8000 distribution size
# 1000 shots per simulation 9000 distribution size
# 2828 shots per simulation 1000 distribution size
# 2828 shots per simulation 2000 distribution size
# 2828 shots per simulation 3000 distribution size
# 2828 shots per simulation 4000 distribution size
# 2828 shots per simulation 5000 distribution size
# 2828 shots per simulation 6000 distribution size
# 2828 shots per simulation 7000 distribution size
# 2828 shots per simulation 8000 distribution size
# 2828 shots per simulation 9000 distribution size
# 5196 shots per simulation 1000 distribution size
# 5196 shots per simulation 2000 distribution size
# 5196 shots per simulation 3000 distribution size
# 5196 shots per simulation 4000 distribution size
# 5196 shots per simulation 5000 distribution size
# 5196 shots per simulation 6000 distribution size
# 5196 shots per simulation 7000 distribution size
# 5196 shots per simulation 8000 distribution size
# 5196 shots per simulation 9000 distribution size
# 8000 shots per simulation 1000 distribution size
# 8000 shots per simulation 2000 distribution size
# 8000 shots per simulation 3000 distribution size
# 8000 shots per simulation 4000 distribution size
# 8000 shots per simulation 5000 distribution size
# 8000 shots per simulation 6000 distribution size
# 8000 shots per simulation 7000 distribution size
# 8000 shots per simulation 8000 distribution size
# 8000 shots per simulation 9000 distribution size
# 11180 shots per simulation 1000 distribution size
# 11180 shots per simulation 2000 distribution size
# 11180 shots per simulation 3000 distribution size
# 11180 shots per simulation 4000 distribution size
# 11180 shots per simulation 5000 distribution size
# 11180 shots per simulation 6000 distribution size
# 11180 shots per simulation 7000 distribution size
# 11180 shots per simulation 8000 distribution size
# 11180 shots per simulation 9000 distribution size
# 14697 shots per simulation 1000 distribution size
# 14697 shots per simulation 2000 distribution size
# 14697 shots per simulation 3000 distribution size
# 14697 shots per simulation 4000 distribution size
# 14697 shots per simulation 5000 distribution size
# 14697 shots per simulation 6000 distribution size
# 14697 shots per simulation 7000 distribution size
# 14697 shots per simulation 8000 distribution size
# 14697 shots per simulation 9000 distribution size
# 18520 shots per simulation 1000 distribution size
# 18520 shots per simulation 2000 distribution size
# 18520 shots per simulation 3000 distribution size
# 18520 shots per simulation 4000 distribution size
# 18520 shots per simulation 5000 distribution size
# 18520 shots per simulation 6000 distribution size
# 18520 shots per simulation 7000 distribution size
# 18520 shots per simulation 8000 distribution size
# 18520 shots per simulation 9000 distribution size
# 22627 shots per simulation 1000 distribution size
# 22627 shots per simulation 2000 distribution size
# 22627 shots per simulation 3000 distribution size
# 22627 shots per simulation 4000 distribution size
# 22627 shots per simulation 5000 distribution size
# 22627 shots per simulation 6000 distribution size
# 22627 shots per simulation 7000 distribution size
# 22627 shots per simulation 8000 distribution size
# 22627 shots per simulation 9000 distribution size
# 27000 shots per simulation 1000 distribution size
# 27000 shots per simulation 2000 distribution size
# 27000 shots per simulation 3000 distribution size
# 27000 shots per simulation 4000 distribution size
# 27000 shots per simulation 5000 distribution size
# 27000 shots per simulation 6000 distribution size
# 27000 shots per simulation 7000 distribution size
# 27000 shots per simulation 8000 distribution size
# 27000 shots per simulation 9000 distribution size
# 31623 shots per simulation 1000 distribution size
# 31623 shots per simulation 2000 distribution size
# 31623 shots per simulation 3000 distribution size
# 31623 shots per simulation 4000 distribution size
# 31623 shots per simulation 5000 distribution size
# 31623 shots per simulation 6000 distribution size
# 31623 shots per simulation 7000 distribution size
# 31623 shots per simulation 8000 distribution size
# 31623 shots per simulation 9000 distribution size
# 36483 shots per simulation 1000 distribution size
# 36483 shots per simulation 2000 distribution size
# 36483 shots per simulation 3000 distribution size
# 36483 shots per simulation 4000 distribution size
# 36483 shots per simulation 5000 distribution size
# 36483 shots per simulation 6000 distribution size
# 36483 shots per simulation 7000 distribution size
# 36483 shots per simulation 8000 distribution size
# 36483 shots per simulation 9000 distribution size
# 41569 shots per simulation 1000 distribution size
# 41569 shots per simulation 2000 distribution size
# 41569 shots per simulation 3000 distribution size
# 41569 shots per simulation 4000 distribution size
# 41569 shots per simulation 5000 distribution size
# 41569 shots per simulation 6000 distribution size
# 41569 shots per simulation 7000 distribution size
# 41569 shots per simulation 8000 distribution size
# 41569 shots per simulation 9000 distribution size
# 46872 shots per simulation 1000 distribution size
# 46872 shots per simulation 2000 distribution size
# 46872 shots per simulation 3000 distribution size
# 46872 shots per simulation 4000 distribution size
# 46872 shots per simulation 5000 distribution size
# 46872 shots per simulation 6000 distribution size
# 46872 shots per simulation 7000 distribution size
# 46872 shots per simulation 8000 distribution size
# 46872 shots per simulation 9000 distribution size
# 52383 shots per simulation 1000 distribution size
# 52383 shots per simulation 2000 distribution size
# 52383 shots per simulation 3000 distribution size
# 52383 shots per simulation 4000 distribution size
# 52383 shots per simulation 5000 distribution size
# 52383 shots per simulation 6000 distribution size
# 52383 shots per simulation 7000 distribution size
# 52383 shots per simulation 8000 distribution size
# 52383 shots per simulation 9000 distribution size
# 58095 shots per simulation 1000 distribution size
# 58095 shots per simulation 2000 distribution size
# 58095 shots per simulation 3000 distribution size
# 58095 shots per simulation 4000 distribution size
# 58095 shots per simulation 5000 distribution size
# 58095 shots per simulation 6000 distribution size
# 58095 shots per simulation 7000 distribution size
# 58095 shots per simulation 8000 distribution size
# 58095 shots per simulation 9000 distribution size
# 64000 shots per simulation 1000 distribution size
# 64000 shots per simulation 2000 distribution size
# 64000 shots per simulation 3000 distribution size
# 64000 shots per simulation 4000 distribution size
# 64000 shots per simulation 5000 distribution size
# 64000 shots per simulation 6000 distribution size
# 64000 shots per simulation 7000 distribution size
# 64000 shots per simulation 8000 distribution size
# 64000 shots per simulation 9000 distribution size
# 70093 shots per simulation 1000 distribution size
# 70093 shots per simulation 2000 distribution size
# 70093 shots per simulation 3000 distribution size
# 70093 shots per simulation 4000 distribution size
# 70093 shots per simulation 5000 distribution size
# 70093 shots per simulation 6000 distribution size
# 70093 shots per simulation 7000 distribution size
# 70093 shots per simulation 8000 distribution size
# 70093 shots per simulation 9000 distribution size
# 76368 shots per simulation 1000 distribution size
# 76368 shots per simulation 2000 distribution size
# 76368 shots per simulation 3000 distribution size
# 76368 shots per simulation 4000 distribution size
# 76368 shots per simulation 5000 distribution size
# 76368 shots per simulation 6000 distribution size
# 76368 shots per simulation 7000 distribution size
# 76368 shots per simulation 8000 distribution size
# 76368 shots per simulation 9000 distribution size
# 82819 shots per simulation 1000 distribution size
# 82819 shots per simulation 2000 distribution size
# 82819 shots per simulation 3000 distribution size
# 82819 shots per simulation 4000 distribution size
# 82819 shots per simulation 5000 distribution size
# 82819 shots per simulation 6000 distribution size
# 82819 shots per simulation 7000 distribution size
# 82819 shots per simulation 8000 distribution size
# 82819 shots per simulation 9000 distribution size

# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %%
np.savetxt("KLDivg_qasm.txt",qasm)

# %% [markdown]
# ## QASM Density matrix Simulator

# %%
backend = QasmSimulator(method='density_matrix')

for x in range(1,20,1):
    print()
arr = []
for nsh in range(1,20,1):
    arr.append([])
    for lp in range(1,10,1):
        nshot=int(round(1000*(nsh)**1.5,0))
        nparam=1000*lp
        fidelity=[]    
        for x in range(nparam):
            qr = QuantumRegister(1)
            cr = ClassicalRegister(1)
            qc = QuantumCircuit(qr, cr)

            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )
            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )

            qc.measure(qr[0],cr[0])
            job = execute(qc, backend, shots=nshot)
            result = job.result()
            count =result.get_counts()

            if '0' in count and '1' in count:
                ratio=count['0']/nshot
            elif '0' in count and '1' not in count:
                ratio=count['0']/nshot
            else:
                ratio=0

            fidelity.append(ratio)   
            #Kullback Leibler divergence
        weights = np.ones_like(fidelity)/float(len(fidelity))            
        P_U_hist=np.histogram(fidelity, bins=bins_list, weights=weights, range=[0, 1])[0];
        #Kullback Leibler divergence
        
        arr[nsh-1].append(sum(rel_entr(P_U_hist, P_harr_hist)))
        print(nshot,'shots per simulation',nparam,'distribution size KL=',sum(rel_entr(P_U_hist, P_harr_hist)))
import sys
import numpy
density_mat=arr
numpy.set_printoptions(threshold=sys.maxsize)
np.savetxt("KLDivg_density_mat.txt",density_mat)
# Out:
# 1000 shots per simulation 1000 distribution size KL= 0.03564651826447743
# 1000 shots per simulation 2000 distribution size KL= 0.020871102437088698
# 1000 shots per simulation 3000 distribution size KL= 0.009621353668631927
# 1000 shots per simulation 4000 distribution size KL= 0.009409601203997454
# 1000 shots per simulation 5000 distribution size KL= 0.006308746387662668
# 1000 shots per simulation 6000 distribution size KL= 0.005914831900824758
# 1000 shots per simulation 7000 distribution size KL= 0.006392087084269407
# 1000 shots per simulation 8000 distribution size KL= 0.00425165359584873
# 1000 shots per simulation 9000 distribution size KL= 0.004147983412343955
# 2828 shots per simulation 1000 distribution size KL= 0.044086933045103055
# 2828 shots per simulation 2000 distribution size KL= 0.019135812431900247
# 2828 shots per simulation 3000 distribution size KL= 0.010911141365261171
# 2828 shots per simulation 4000 distribution size KL= 0.009132750717624025

# %%
density_mat

# %% [markdown]
# ## StateVector

# %%
backend = QasmSimulator(method='statevector')

for x in range(1,20,1):
    print()
arr = []
for nsh in range(1,20,1):
    arr.append([])
    for lp in range(1,10,1):
        nshot=int(round(1000*(nsh)**1.5,0))
        nparam=1000*lp
        fidelity=[]    
        for x in range(nparam):
            qr = QuantumRegister(1)
            cr = ClassicalRegister(1)
            qc = QuantumCircuit(qr, cr)

            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )
            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )

            qc.measure(qr[0],cr[0])
            job = execute(qc, backend, shots=nshot)
            result = job.result()
            count =result.get_counts()

            if '0' in count and '1' in count:
                ratio=count['0']/nshot
            elif '0' in count and '1' not in count:
                ratio=count['0']/nshot
            else:
                ratio=0

            fidelity.append(ratio)   
            #Kullback Leibler divergence
        weights = np.ones_like(fidelity)/float(len(fidelity))            
        P_U_hist=np.histogram(fidelity, bins=bins_list, weights=weights, range=[0, 1])[0];
        #Kullback Leibler divergence
        
        arr[nsh-1].append(sum(rel_entr(P_U_hist, P_harr_hist)))
        print(nshot,'shots per simulation',nparam,'distribution size KL=',sum(rel_entr(P_U_hist, P_harr_hist)))
import sys
import numpy
statevector1=arr
numpy.set_printoptions(threshold=sys.maxsize)
np.savetxt("KLDivg_statevector.txt",statevector1)

# %%
statevector1

# %% [markdown]
# ## stabilizer

# %%
backend = QasmSimulator(method='stabilizer')

for x in range(1,20,1):
    print()
arr = []
for nsh in range(1,20,1):
    arr.append([])
    for lp in range(1,10,1):
        nshot=int(round(1000*(nsh)**1.5,0))
        nparam=1000*lp
        fidelity=[]    
        for x in range(nparam):
            qr = QuantumRegister(1)
            cr = ClassicalRegister(1)
            qc = QuantumCircuit(qr, cr)

            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )
            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )

            qc.measure(qr[0],cr[0])
            job = execute(qc, backend, shots=nshot)
            result = job.result()
            count =result.get_counts()

            if '0' in count and '1' in count:
                ratio=count['0']/nshot
            elif '0' in count and '1' not in count:
                ratio=count['0']/nshot
            else:
                ratio=0

            fidelity.append(ratio)   
            #Kullback Leibler divergence
        weights = np.ones_like(fidelity)/float(len(fidelity))            
        P_U_hist=np.histogram(fidelity, bins=bins_list, weights=weights, range=[0, 1])[0];
        #Kullback Leibler divergence
        
        arr[nsh-1].append(sum(rel_entr(P_U_hist, P_harr_hist)))
        print(nshot,'shots per simulation',nparam,'distribution size KL=',sum(rel_entr(P_U_hist, P_harr_hist)))
import sys
import numpy
stabilizer1=arr
numpy.set_printoptions(threshold=sys.maxsize)
np.savetxt("KLDivg_stabilizer.txt",stabilizer1)

# %%
stabilizer1

# %% [markdown]
# ## extended_stabilizer

# %%
backend = QasmSimulator(method='extended_stabilizer')

for x in range(1,20,1):
    print()
arr = []
for nsh in range(1,20,1):
    arr.append([])
    for lp in range(1,10,1):
        nshot=int(round(1000*(nsh)**1.5,0))
        nparam=1000*lp
        fidelity=[]    
        for x in range(nparam):
            qr = QuantumRegister(1)
            cr = ClassicalRegister(1)
            qc = QuantumCircuit(qr, cr)

            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )
            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )

            qc.measure(qr[0],cr[0])
            job = execute(qc, backend, shots=nshot)
            result = job.result()
            count =result.get_counts()

            if '0' in count and '1' in count:
                ratio=count['0']/nshot
            elif '0' in count and '1' not in count:
                ratio=count['0']/nshot
            else:
                ratio=0

            fidelity.append(ratio)   
            #Kullback Leibler divergence
        weights = np.ones_like(fidelity)/float(len(fidelity))            
        P_U_hist=np.histogram(fidelity, bins=bins_list, weights=weights, range=[0, 1])[0];
        #Kullback Leibler divergence
        
        arr[nsh-1].append(sum(rel_entr(P_U_hist, P_harr_hist)))
        print(nshot,'shots per simulation',nparam,'distribution size KL=',sum(rel_entr(P_U_hist, P_harr_hist)))
import sys
import numpy
extended_stabilizer1=arr
numpy.set_printoptions(threshold=sys.maxsize)
np.savetxt("KLDivg_extended_stabilizer.txt",extended_stabilizer1)

# %%
extended_stabilizer1

# %% [markdown]
# ## matrix_product_state

# %%
backend = QasmSimulator(method='matrix_product_state')

for x in range(1,20,1):
    print()
arr = []
for nsh in range(1,20,1):
    arr.append([])
    for lp in range(1,10,1):
        nshot=int(round(1000*(nsh)**1.5,0))
        nparam=1000*lp
        fidelity=[]    
        for x in range(nparam):
            qr = QuantumRegister(1)
            cr = ClassicalRegister(1)
            qc = QuantumCircuit(qr, cr)

            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )
            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )

            qc.measure(qr[0],cr[0])
            job = execute(qc, backend, shots=nshot)
            result = job.result()
            count =result.get_counts()

            if '0' in count and '1' in count:
                ratio=count['0']/nshot
            elif '0' in count and '1' not in count:
                ratio=count['0']/nshot
            else:
                ratio=0

            fidelity.append(ratio)   
            #Kullback Leibler divergence
        weights = np.ones_like(fidelity)/float(len(fidelity))            
        P_U_hist=np.histogram(fidelity, bins=bins_list, weights=weights, range=[0, 1])[0];
        #Kullback Leibler divergence
        
        arr[nsh-1].append(sum(rel_entr(P_U_hist, P_harr_hist)))
        print(nshot,'shots per simulation',nparam,'distribution size KL=',sum(rel_entr(P_U_hist, P_harr_hist)))
import sys
import numpy
matrix_product1=arr
numpy.set_printoptions(threshold=sys.maxsize)
np.savetxt("KLDivg_matrix_product1.txt",matrix_product1)

# %%
matrix_product1

# %%
def plotdata(i):
    klll=np.transpose(qasm)
    x=[];
    y=[];
    for nsh in range(0,9,1):
        x.append(int(round(1000*(nsh)**1.5,0)))
        y.append(klll[nsh][i])
    return [x,y]

def plotdata2(i):
    klll=np.transpose(statevector)
    x=[];
    y=[];
    for nsh in range(0,9,1):
        x.append(int(round(1000*(nsh)**1.5,0)))
        y.append(klll[nsh][i])
    return [x,y]

# %% [markdown]
# ## QASM simulator

# %%
import pandas as pd
import matplotlib.pyplot as plt

#loading dataset


plt.plot(plotdata(0)[0],plotdata(0)[1], color='red', label='npram=1000');
plt.plot(plotdata(1)[0],plotdata(1)[1], color='blue', label='npram=2000');
plt.plot(plotdata(2)[0],plotdata(2)[1], color='black', label='npram=3000');
plt.plot(plotdata(3)[0],plotdata(3)[1], color='green', label='npram=4000');
plt.plot(plotdata(4)[0],plotdata(4)[1], color='purple',  label='npram=5000');
plt.plot(plotdata(5)[0],plotdata(5)[1], color='gray',  label='npram=6000');
plt.plot(plotdata(6)[0],plotdata(6)[1], color='black',  label='npram=7000');
plt.plot(plotdata(7)[0],plotdata(7)[1], color='yellow',  label='npram=8000');


plt.legend(loc='upper right')

plt.yscale('log',base=10) 
plt.ylabel('Expressibility')

# Create names on the x axis

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

#loading dataset


plt.plot(plotdata2(0)[0],plotdata2(0)[1], color='red', label='npram=1000');
plt.plot(plotdata2(1)[0],plotdata2(1)[1], color='blue', label='npram=2000');
plt.plot(plotdata2(2)[0],plotdata2(2)[1], color='black', label='npram=3000');
plt.plot(plotdata2(3)[0],plotdata2(3)[1], color='green', label='npram=4000');
plt.plot(plotdata2(4)[0],plotdata2(4)[1], color='purple',  label='npram=5000');
plt.plot(plotdata2(5)[0],plotdata2(5)[1], color='gray',  label='npram=6000');
plt.plot(plotdata2(6)[0],plotdata2(6)[1], color='black',  label='npram=7000');
plt.plot(plotdata2(7)[0],plotdata2(7)[1], color='yellow',  label='npram=8000');


plt.legend(loc='upper right')

plt.yscale('log',base=10) 
plt.ylabel('Expressibility')

# Create names on the x axis

plt.show()
