# %% [markdown]
# # Understand the behavior of number of the shots and simulator
#
# Since the number of the shots from the simulator play role in the accuracy and the expressibilty, we want to further study the effect of the those parameters.
#
# In this document, we will only focus on the arbitary circuit since it should give identical result with the harr distribution.

# %%
from matplotlib import pyplot
from qiskit import *
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import IBMQ, Aer, execute,assemble,QuantumCircuit, aqua
from qiskit.visualization import plot_histogram, plot_bloch_vector, plot_bloch_multivector
from qiskit.quantum_info import Statevector
from qiskit.extensions import *
provider = IBMQ.load_account()

from qiskit.quantum_info import random_unitary
from qiskit.providers.aer import QasmSimulator, StatevectorSimulator, UnitarySimulator
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import math
from math import pi, sqrt

from scipy.special import rel_entr
from random import seed
from random import random
import cmath
# Out:
# C:\Users\Saesun Kim\anaconda3\envs\name_of_my_env\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '
# ibmqfactory.load_account:WARNING:2021-03-21 00:35:02,909: Credentials are already in use. The existing account in the session will be replaced.

# %%
#Possible Bin
bins_list=[];
for i in range(76):
    bins_list.append((i)/75)
#Center of the Bean
bins_x=[]    
for i in range(75):
    bins_x.append(bins_list[1]+bins_list[i])
def P_harr(l,u,N):
    return (1-l)**(N-1)-(1-u)**(N-1)
#Harr historgram
P_harr_hist=[]
for i in range(75):
    P_harr_hist.append(P_harr(bins_list[i],bins_list[i+1],2))    
#Imaginary    
j=(-1)**(1/2)

# %% [markdown]
# ## Arbitary Unitary Qasm_simulator

# %%
backend = Aer.get_backend('qasm_simulator')
for x in range(1,20,1):
    print()
arr = []
for nsh in range(1,20,1):
    arr.append([])
    for lp in range(1,10,1):
        nshot=int(round(1000*(nsh)**1.5,0))
        nparam=1000*lp
        fidelity=[]    
        for x in range(nparam):
            qr = QuantumRegister(1)
            cr = ClassicalRegister(1)
            qc = QuantumCircuit(qr, cr)

            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )
            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )

            qc.measure(qr[0],cr[0])
            job = execute(qc, backend, shots=nshot)
            result = job.result()
            count =result.get_counts()

            if '0' in count and '1' in count:
                ratio=count['0']/nshot
            elif '0' in count and '1' not in count:
                ratio=count['0']/nshot
            else:
                ratio=0

            fidelity.append(ratio)   
            #Kullback Leibler divergence
        weights = np.ones_like(fidelity)/float(len(fidelity))            
        P_U_hist=np.histogram(fidelity, bins=bins_list, weights=weights, range=[0, 1])[0];
        #Kullback Leibler divergence
        print(nshot,'shots per simulation',nparam,'distribution size')
        arr[nsh-1].append(sum(rel_entr(P_U_hist, P_harr_hist)))
# Out:
# 1000 shots per simulation 1000 distribution size
# 1000 shots per simulation 2000 distribution size
# 1000 shots per simulation 3000 distribution size
# 1000 shots per simulation 4000 distribution size
# 1000 shots per simulation 5000 distribution size
# 1000 shots per simulation 6000 distribution size
# 1000 shots per simulation 7000 distribution size
# 1000 shots per simulation 8000 distribution size
# 1000 shots per simulation 9000 distribution size
# 2828 shots per simulation 1000 distribution size
# 2828 shots per simulation 2000 distribution size
# 2828 shots per simulation 3000 distribution size
# 2828 shots per simulation 4000 distribution size
# 2828 shots per simulation 5000 distribution size
# 2828 shots per simulation 6000 distribution size
# 2828 shots per simulation 7000 distribution size
# 2828 shots per simulation 8000 distribution size
# 2828 shots per simulation 9000 distribution size
# 5196 shots per simulation 1000 distribution size
# 5196 shots per simulation 2000 distribution size
# 5196 shots per simulation 3000 distribution size
# 5196 shots per simulation 4000 distribution size
# 5196 shots per simulation 5000 distribution size
# 5196 shots per simulation 6000 distribution size
# 5196 shots per simulation 7000 distribution size
# 5196 shots per simulation 8000 distribution size
# 5196 shots per simulation 9000 distribution size
# 8000 shots per simulation 1000 distribution size
# 8000 shots per simulation 2000 distribution size
# 8000 shots per simulation 3000 distribution size
# 8000 shots per simulation 4000 distribution size
# 8000 shots per simulation 5000 distribution size
# 8000 shots per simulation 6000 distribution size
# 8000 shots per simulation 7000 distribution size
# 8000 shots per simulation 8000 distribution size
# 8000 shots per simulation 9000 distribution size
# 11180 shots per simulation 1000 distribution size
# 11180 shots per simulation 2000 distribution size
# 11180 shots per simulation 3000 distribution size
# 11180 shots per simulation 4000 distribution size
# 11180 shots per simulation 5000 distribution size
# 11180 shots per simulation 6000 distribution size
# 11180 shots per simulation 7000 distribution size
# 11180 shots per simulation 8000 distribution size
# 11180 shots per simulation 9000 distribution size
# 14697 shots per simulation 1000 distribution size
# 14697 shots per simulation 2000 distribution size
# 14697 shots per simulation 3000 distribution size
# 14697 shots per simulation 4000 distribution size
# 14697 shots per simulation 5000 distribution size
# 14697 shots per simulation 6000 distribution size
# 14697 shots per simulation 7000 distribution size
# 14697 shots per simulation 8000 distribution size
# 14697 shots per simulation 9000 distribution size
# 18520 shots per simulation 1000 distribution size
# 18520 shots per simulation 2000 distribution size
# 18520 shots per simulation 3000 distribution size
# 18520 shots per simulation 4000 distribution size
# 18520 shots per simulation 5000 distribution size
# 18520 shots per simulation 6000 distribution size
# 18520 shots per simulation 7000 distribution size
# 18520 shots per simulation 8000 distribution size
# 18520 shots per simulation 9000 distribution size
# 22627 shots per simulation 1000 distribution size
# 22627 shots per simulation 2000 distribution size
# 22627 shots per simulation 3000 distribution size
# 22627 shots per simulation 4000 distribution size
# 22627 shots per simulation 5000 distribution size
# 22627 shots per simulation 6000 distribution size
# 22627 shots per simulation 7000 distribution size
# 22627 shots per simulation 8000 distribution size
# 22627 shots per simulation 9000 distribution size
# 27000 shots per simulation 1000 distribution size
# 27000 shots per simulation 2000 distribution size
# 27000 shots per simulation 3000 distribution size
# 27000 shots per simulation 4000 distribution size
# 27000 shots per simulation 5000 distribution size
# 27000 shots per simulation 6000 distribution size
# 27000 shots per simulation 7000 distribution size
# 27000 shots per simulation 8000 distribution size
# 27000 shots per simulation 9000 distribution size
# 31623 shots per simulation 1000 distribution size
# 31623 shots per simulation 2000 distribution size
# 31623 shots per simulation 3000 distribution size
# 31623 shots per simulation 4000 distribution size
# 31623 shots per simulation 5000 distribution size
# 31623 shots per simulation 6000 distribution size
# 31623 shots per simulation 7000 distribution size
# 31623 shots per simulation 8000 distribution size
# 31623 shots per simulation 9000 distribution size
# 36483 shots per simulation 1000 distribution size
# 36483 shots per simulation 2000 distribution size
# 36483 shots per simulation 3000 distribution size
# 36483 shots per simulation 4000 distribution size
# 36483 shots per simulation 5000 distribution size
# 36483 shots per simulation 6000 distribution size
# 36483 shots per simulation 7000 distribution size
# 36483 shots per simulation 8000 distribution size
# 36483 shots per simulation 9000 distribution size
# 41569 shots per simulation 1000 distribution size
# 41569 shots per simulation 2000 distribution size
# 41569 shots per simulation 3000 distribution size
# 41569 shots per simulation 4000 distribution size
# 41569 shots per simulation 5000 distribution size
# 41569 shots per simulation 6000 distribution size
# 41569 shots per simulation 7000 distribution size
# 41569 shots per simulation 8000 distribution size
# 41569 shots per simulation 9000 distribution size
# 46872 shots per simulation 1000 distribution size
# 46872 shots per simulation 2000 distribution size
# 46872 shots per simulation 3000 distribution size
# 46872 shots per simulation 4000 distribution size
# 46872 shots per simulation 5000 distribution size
# 46872 shots per simulation 6000 distribution size
# 46872 shots per simulation 7000 distribution size
# 46872 shots per simulation 8000 distribution size
# 46872 shots per simulation 9000 distribution size
# 52383 shots per simulation 1000 distribution size
# 52383 shots per simulation 2000 distribution size
# 52383 shots per simulation 3000 distribution size
# 52383 shots per simulation 4000 distribution size
# 52383 shots per simulation 5000 distribution size
# 52383 shots per simulation 6000 distribution size
# 52383 shots per simulation 7000 distribution size
# 52383 shots per simulation 8000 distribution size
# 52383 shots per simulation 9000 distribution size
# 58095 shots per simulation 1000 distribution size
# 58095 shots per simulation 2000 distribution size
# 58095 shots per simulation 3000 distribution size
# 58095 shots per simulation 4000 distribution size
# 58095 shots per simulation 5000 distribution size
# 58095 shots per simulation 6000 distribution size
# 58095 shots per simulation 7000 distribution size
# 58095 shots per simulation 8000 distribution size
# 58095 shots per simulation 9000 distribution size
# 64000 shots per simulation 1000 distribution size
# 64000 shots per simulation 2000 distribution size
# 64000 shots per simulation 3000 distribution size
# 64000 shots per simulation 4000 distribution size
# 64000 shots per simulation 5000 distribution size
# 64000 shots per simulation 6000 distribution size
# 64000 shots per simulation 7000 distribution size
# 64000 shots per simulation 8000 distribution size
# 64000 shots per simulation 9000 distribution size
# 70093 shots per simulation 1000 distribution size
# 70093 shots per simulation 2000 distribution size
# 70093 shots per simulation 3000 distribution size
# 70093 shots per simulation 4000 distribution size
# 70093 shots per simulation 5000 distribution size
# 70093 shots per simulation 6000 distribution size
# 70093 shots per simulation 7000 distribution size
# 70093 shots per simulation 8000 distribution size
# 70093 shots per simulation 9000 distribution size
# 76368 shots per simulation 1000 distribution size
# 76368 shots per simulation 2000 distribution size
# 76368 shots per simulation 3000 distribution size
# 76368 shots per simulation 4000 distribution size
# 76368 shots per simulation 5000 distribution size
# 76368 shots per simulation 6000 distribution size
# 76368 shots per simulation 7000 distribution size
# 76368 shots per simulation 8000 distribution size
# 76368 shots per simulation 9000 distribution size
# 82819 shots per simulation 1000 distribution size
# 82819 shots per simulation 2000 distribution size
# 82819 shots per simulation 3000 distribution size
# 82819 shots per simulation 4000 distribution size
# 82819 shots per simulation 5000 distribution size
# 82819 shots per simulation 6000 distribution size
# 82819 shots per simulation 7000 distribution size
# 82819 shots per simulation 8000 distribution size
# 82819 shots per simulation 9000 distribution size

# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %%
np.savetxt("KLDivg_qasm.txt",qasm)

# %%
qasm

# %% [markdown]
# ## QASM Density matrix Simulator

# %%
backend = QasmSimulator(method='density_matrix')

for x in range(1,20,1):
    print()
arr = []
for nsh in range(1,20,1):
    arr.append([])
    for lp in range(1,10,1):
        nshot=int(round(1000*(nsh)**1.5,0))
        nparam=1000*lp
        fidelity=[]    
        for x in range(nparam):
            qr = QuantumRegister(1)
            cr = ClassicalRegister(1)
            qc = QuantumCircuit(qr, cr)

            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )
            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )

            qc.measure(qr[0],cr[0])
            job = execute(qc, backend, shots=nshot)
            result = job.result()
            count =result.get_counts()

            if '0' in count and '1' in count:
                ratio=count['0']/nshot
            elif '0' in count and '1' not in count:
                ratio=count['0']/nshot
            else:
                ratio=0

            fidelity.append(ratio)   
            #Kullback Leibler divergence
        weights = np.ones_like(fidelity)/float(len(fidelity))            
        P_U_hist=np.histogram(fidelity, bins=bins_list, weights=weights, range=[0, 1])[0];
        #Kullback Leibler divergence
        
        arr[nsh-1].append(sum(rel_entr(P_U_hist, P_harr_hist)))
        print(nshot,'shots per simulation',nparam,'distribution size KL=',sum(rel_entr(P_U_hist, P_harr_hist)))
import sys
import numpy
density_mat=arr
numpy.set_printoptions(threshold=sys.maxsize)
np.savetxt("KLDivg_density_mat.txt",density_mat)
# Out:
# 1000 shots per simulation 1000 distribution size KL= 0.03564651826447743
# 1000 shots per simulation 2000 distribution size KL= 0.020871102437088698
# 1000 shots per simulation 3000 distribution size KL= 0.009621353668631927
# 1000 shots per simulation 4000 distribution size KL= 0.009409601203997454
# 1000 shots per simulation 5000 distribution size KL= 0.006308746387662668
# 1000 shots per simulation 6000 distribution size KL= 0.005914831900824758
# 1000 shots per simulation 7000 distribution size KL= 0.006392087084269407
# 1000 shots per simulation 8000 distribution size KL= 0.00425165359584873
# 1000 shots per simulation 9000 distribution size KL= 0.004147983412343955
# 2828 shots per simulation 1000 distribution size KL= 0.044086933045103055
# 2828 shots per simulation 2000 distribution size KL= 0.019135812431900247
# 2828 shots per simulation 3000 distribution size KL= 0.010911141365261171
# 2828 shots per simulation 4000 distribution size KL= 0.009132750717624025
# 2828 shots per simulation 5000 distribution size KL= 0.011456244793761339
# 2828 shots per simulation 6000 distribution size KL= 0.007954516335748306
# 2828 shots per simulation 7000 distribution size KL= 0.005548031200585661
# 2828 shots per simulation 8000 distribution size KL= 0.0050854230510299575
# 2828 shots per simulation 9000 distribution size KL= 0.00401078400764941
# 5196 shots per simulation 1000 distribution size KL= 0.03571895502509018
# 5196 shots per simulation 2000 distribution size KL= 0.01682436611800507
# 5196 shots per simulation 3000 distribution size KL= 0.010786138672289785
# 5196 shots per simulation 4000 distribution size KL= 0.010828746473646397
# 5196 shots per simulation 5000 distribution size KL= 0.006992614425849317
# 5196 shots per simulation 6000 distribution size KL= 0.007279571587854724
# 5196 shots per simulation 7000 distribution size KL= 0.00414776126880919
# 5196 shots per simulation 8000 distribution size KL= 0.003739961405752186
# 5196 shots per simulation 9000 distribution size KL= 0.005486135115020914
# 8000 shots per simulation 1000 distribution size KL= 0.039476734955802395
# 8000 shots per simulation 2000 distribution size KL= 0.016409300080272506
# 8000 shots per simulation 3000 distribution size KL= 0.008200923235182732
# 8000 shots per simulation 4000 distribution size KL= 0.011516938807969914
# 8000 shots per simulation 5000 distribution size KL= 0.00694654376979589
# 8000 shots per simulation 6000 distribution size KL= 0.005264497436269632
# 8000 shots per simulation 7000 distribution size KL= 0.004612729335821585
# 8000 shots per simulation 8000 distribution size KL= 0.005112412943663227
# 8000 shots per simulation 9000 distribution size KL= 0.003404652782912028
# 11180 shots per simulation 1000 distribution size KL= 0.04130876079127352
# 11180 shots per simulation 2000 distribution size KL= 0.016851668610049983
# 11180 shots per simulation 3000 distribution size KL= 0.01390260895799241
# 11180 shots per simulation 4000 distribution size KL= 0.012257138489260268
# 11180 shots per simulation 5000 distribution size KL= 0.005894233544851029
# 11180 shots per simulation 6000 distribution size KL= 0.004655576355391742
# 11180 shots per simulation 7000 distribution size KL= 0.006340359627043174
# 11180 shots per simulation 8000 distribution size KL= 0.0036827380184733553
# 11180 shots per simulation 9000 distribution size KL= 0.004136516045619886
# 14697 shots per simulation 1000 distribution size KL= 0.049091848479399874
# 14697 shots per simulation 2000 distribution size KL= 0.01351670413376896
# 14697 shots per simulation 3000 distribution size KL= 0.013006947078007626
# 14697 shots per simulation 4000 distribution size KL= 0.008027793816699647
# 14697 shots per simulation 5000 distribution size KL= 0.007699328890095485
# 14697 shots per simulation 6000 distribution size KL= 0.006330057175422081
# 14697 shots per simulation 7000 distribution size KL= 0.004217673643980483
# 14697 shots per simulation 8000 distribution size KL= 0.004699628326615796
# 14697 shots per simulation 9000 distribution size KL= 0.004128447255555146
# 18520 shots per simulation 1000 distribution size KL= 0.03997746798002719
# 18520 shots per simulation 2000 distribution size KL= 0.019144040729306266
# 18520 shots per simulation 3000 distribution size KL= 0.013729872930692284
# 18520 shots per simulation 4000 distribution size KL= 0.007402430221031022
# 18520 shots per simulation 5000 distribution size KL= 0.00820980322254333
# 18520 shots per simulation 6000 distribution size KL= 0.008183171025207407
# 18520 shots per simulation 7000 distribution size KL= 0.004545570563640735
# 18520 shots per simulation 8000 distribution size KL= 0.0038592087832983344
# 18520 shots per simulation 9000 distribution size KL= 0.00427987220333396
# 22627 shots per simulation 1000 distribution size KL= 0.03530273437028731
# 22627 shots per simulation 2000 distribution size KL= 0.019279345574853737
# 22627 shots per simulation 3000 distribution size KL= 0.010633778402045387
# 22627 shots per simulation 4000 distribution size KL= 0.008412544575131688
# 22627 shots per simulation 5000 distribution size KL= 0.008044332642236989
# 22627 shots per simulation 6000 distribution size KL= 0.005515575178788324
# 22627 shots per simulation 7000 distribution size KL= 0.004482098907847994
# 22627 shots per simulation 8000 distribution size KL= 0.003956679487233089
# 22627 shots per simulation 9000 distribution size KL= 0.003408026388188618
# 27000 shots per simulation 1000 distribution size KL= 0.04213925946487424
# 27000 shots per simulation 2000 distribution size KL= 0.016997750887436276
# 27000 shots per simulation 3000 distribution size KL= 0.010341417956067871
# 27000 shots per simulation 4000 distribution size KL= 0.007081906690527877
# 27000 shots per simulation 5000 distribution size KL= 0.00612914549753512
# 27000 shots per simulation 6000 distribution size KL= 0.00523207470454761
# 27000 shots per simulation 7000 distribution size KL= 0.004709726122050212
# 27000 shots per simulation 8000 distribution size KL= 0.004760293299456328
# 27000 shots per simulation 9000 distribution size KL= 0.0033127720837559807
# 31623 shots per simulation 1000 distribution size KL= 0.04407175289366935
# 31623 shots per simulation 2000 distribution size KL= 0.016564065616182337
# 31623 shots per simulation 3000 distribution size KL= 0.014946101630351696
# 31623 shots per simulation 4000 distribution size KL= 0.007309402710959329
# 31623 shots per simulation 5000 distribution size KL= 0.00822373023432124
# 31623 shots per simulation 6000 distribution size KL= 0.007083734048027058
# 31623 shots per simulation 7000 distribution size KL= 0.0052331106662861174
# 31623 shots per simulation 8000 distribution size KL= 0.005528809724844206
# 31623 shots per simulation 9000 distribution size KL= 0.0038397773448159804
# 36483 shots per simulation 1000 distribution size KL= 0.04648390692237689
# 36483 shots per simulation 2000 distribution size KL= 0.016213351696080996
# 36483 shots per simulation 3000 distribution size KL= 0.009671714230937814
# 36483 shots per simulation 4000 distribution size KL= 0.0082438217914532
# 36483 shots per simulation 5000 distribution size KL= 0.008251408296248748
# 36483 shots per simulation 6000 distribution size KL= 0.005440098508280602
# 36483 shots per simulation 7000 distribution size KL= 0.005040296400553081
# 36483 shots per simulation 8000 distribution size KL= 0.006014039202780445
# 36483 shots per simulation 9000 distribution size KL= 0.0027725279730141075
# 41569 shots per simulation 1000 distribution size KL= 0.041244021846582136
# 41569 shots per simulation 2000 distribution size KL= 0.014171580629190885
# 41569 shots per simulation 3000 distribution size KL= 0.013159658924507987
# 41569 shots per simulation 4000 distribution size KL= 0.009612846113925275
# 41569 shots per simulation 5000 distribution size KL= 0.006272951006948181
# 41569 shots per simulation 6000 distribution size KL= 0.006605902070833347
# 41569 shots per simulation 7000 distribution size KL= 0.005126857105983653
# 41569 shots per simulation 8000 distribution size KL= 0.005858007592199694
# 41569 shots per simulation 9000 distribution size KL= 0.003854447024475383
# 46872 shots per simulation 1000 distribution size KL= 0.03304567330300567
# 46872 shots per simulation 2000 distribution size KL= 0.017990437630174272
# 46872 shots per simulation 3000 distribution size KL= 0.01086011589451763
# 46872 shots per simulation 4000 distribution size KL= 0.009510903150504617
# 46872 shots per simulation 5000 distribution size KL= 0.008768308271919932
# 46872 shots per simulation 6000 distribution size KL= 0.004751058694676031
# 46872 shots per simulation 7000 distribution size KL= 0.005070110092897409
# 46872 shots per simulation 8000 distribution size KL= 0.00341172062922741
# 46872 shots per simulation 9000 distribution size KL= 0.0042574841839134675
# 52383 shots per simulation 1000 distribution size KL= 0.03320466567744195
# 52383 shots per simulation 2000 distribution size KL= 0.025521166076559115
# 52383 shots per simulation 3000 distribution size KL= 0.010685522660736746
# 52383 shots per simulation 4000 distribution size KL= 0.007172840693268035
# 52383 shots per simulation 5000 distribution size KL= 0.006849285528301366
# 52383 shots per simulation 6000 distribution size KL= 0.005020445611424899
# 52383 shots per simulation 7000 distribution size KL= 0.00500945186559848
# 52383 shots per simulation 8000 distribution size KL= 0.006288695397562577
# 52383 shots per simulation 9000 distribution size KL= 0.004578901180264245
# 58095 shots per simulation 1000 distribution size KL= 0.03842354938612774
# 58095 shots per simulation 2000 distribution size KL= 0.012276676222837006
# 58095 shots per simulation 3000 distribution size KL= 0.011034413113355788
# 58095 shots per simulation 4000 distribution size KL= 0.009654533362011143
# 58095 shots per simulation 5000 distribution size KL= 0.008229714547939967
# 58095 shots per simulation 6000 distribution size KL= 0.0058252928239891704
# 58095 shots per simulation 7000 distribution size KL= 0.005369027243514391
# 58095 shots per simulation 8000 distribution size KL= 0.005744819665899928
# 58095 shots per simulation 9000 distribution size KL= 0.0035615709935351023
# 64000 shots per simulation 1000 distribution size KL= 0.043812835063847554
# 64000 shots per simulation 2000 distribution size KL= 0.015848630896938342
# 64000 shots per simulation 3000 distribution size KL= 0.010977104631285513
# 64000 shots per simulation 4000 distribution size KL= 0.01038434579875008
# 64000 shots per simulation 5000 distribution size KL= 0.007717747128324293
# 64000 shots per simulation 6000 distribution size KL= 0.008119283852531469
# 64000 shots per simulation 7000 distribution size KL= 0.005144808592677446
# 64000 shots per simulation 8000 distribution size KL= 0.0031733257594115374
# 64000 shots per simulation 9000 distribution size KL= 0.003956083510494699
# 70093 shots per simulation 1000 distribution size KL= 0.034781834467606396
# 70093 shots per simulation 2000 distribution size KL= 0.016993901939018886
# 70093 shots per simulation 3000 distribution size KL= 0.010026321778935483
# 70093 shots per simulation 4000 distribution size KL= 0.007500369139452655
# 70093 shots per simulation 5000 distribution size KL= 0.007338956079328374
# 70093 shots per simulation 6000 distribution size KL= 0.005120953166472334
# 70093 shots per simulation 7000 distribution size KL= 0.005356719238017688
# 70093 shots per simulation 8000 distribution size KL= 0.0031979470676142914
# 70093 shots per simulation 9000 distribution size KL= 0.005971077933135757
# 76368 shots per simulation 1000 distribution size KL= 0.05054151247745509
# 76368 shots per simulation 2000 distribution size KL= 0.02370669785990934
# 76368 shots per simulation 3000 distribution size KL= 0.011531073588003414
# 76368 shots per simulation 4000 distribution size KL= 0.010204473023775862
# 76368 shots per simulation 5000 distribution size KL= 0.009493927548998223
# 76368 shots per simulation 6000 distribution size KL= 0.00919310907793246
# 76368 shots per simulation 7000 distribution size KL= 0.004874296066344133
# 76368 shots per simulation 8000 distribution size KL= 0.0038587352040526956
# 76368 shots per simulation 9000 distribution size KL= 0.004155284237531752
# 82819 shots per simulation 1000 distribution size KL= 0.032930953937648964
# 82819 shots per simulation 2000 distribution size KL= 0.015735628242975423
# 82819 shots per simulation 3000 distribution size KL= 0.014269009102583458
# 82819 shots per simulation 4000 distribution size KL= 0.008495179084137721
# 82819 shots per simulation 5000 distribution size KL= 0.007665724944317257
# 82819 shots per simulation 6000 distribution size KL= 0.005355915060769977
# 82819 shots per simulation 7000 distribution size KL= 0.004238837955426452
# 82819 shots per simulation 8000 distribution size KL= 0.0038021018443400835
# 82819 shots per simulation 9000 distribution size KL= 0.0034084141311917573

# %%
density_mat
# Out:
# [[0.03564651826447743,
#   0.020871102437088698,
#   0.009621353668631927,
#   0.009409601203997454,
#   0.006308746387662668,
#   0.005914831900824758,
#   0.006392087084269407,
#   0.00425165359584873,
#   0.004147983412343955],
#  [0.044086933045103055,
#   0.019135812431900247,
#   0.010911141365261171,
#   0.009132750717624025,
#   0.011456244793761339,
#   0.007954516335748306,
#   0.005548031200585661,
#   0.0050854230510299575,
#   0.00401078400764941],
#  [0.03571895502509018,
#   0.01682436611800507,
#   0.010786138672289785,
#   0.010828746473646397,
#   0.006992614425849317,
#   0.007279571587854724,
#   0.00414776126880919,
#   0.003739961405752186,
#   0.005486135115020914],
#  [0.039476734955802395,
#   0.016409300080272506,
#   0.008200923235182732,
#   0.011516938807969914,
#   0.00694654376979589,
#   0.005264497436269632,
#   0.004612729335821585,
#   0.005112412943663227,
#   0.003404652782912028],
#  [0.04130876079127352,
#   0.016851668610049983,
#   0.01390260895799241,
#   0.012257138489260268,
#   0.005894233544851029,
#   0.004655576355391742,
#   0.006340359627043174,
#   0.0036827380184733553,
#   0.004136516045619886],
#  [0.049091848479399874,
#   0.01351670413376896,
#   0.013006947078007626,
#   0.008027793816699647,
#   0.007699328890095485,
#   0.006330057175422081,
#   0.004217673643980483,
#   0.004699628326615796,
#   0.004128447255555146],
#  [0.03997746798002719,
#   0.019144040729306266,
#   0.013729872930692284,
#   0.007402430221031022,
#   0.00820980322254333,
#   0.008183171025207407,
#   0.004545570563640735,
#   0.0038592087832983344,
#   0.00427987220333396],
#  [0.03530273437028731,
#   0.019279345574853737,
#   0.010633778402045387,
#   0.008412544575131688,
#   0.008044332642236989,
#   0.005515575178788324,
#   0.004482098907847994,
#   0.003956679487233089,
#   0.003408026388188618],
#  [0.04213925946487424,
#   0.016997750887436276,
#   0.010341417956067871,
#   0.007081906690527877,
#   0.00612914549753512,
#   0.00523207470454761,
#   0.004709726122050212,
#   0.004760293299456328,
#   0.0033127720837559807],
#  [0.04407175289366935,
#   0.016564065616182337,
#   0.014946101630351696,
#   0.007309402710959329,
#   0.00822373023432124,
#   0.007083734048027058,
#   0.0052331106662861174,
#   0.005528809724844206,
#   0.0038397773448159804],
#  [0.04648390692237689,
#   0.016213351696080996,
#   0.009671714230937814,
#   0.0082438217914532,
#   0.008251408296248748,
#   0.005440098508280602,
#   0.005040296400553081,
#   0.006014039202780445,
#   0.0027725279730141075],
#  [0.041244021846582136,
#   0.014171580629190885,
#   0.013159658924507987,
#   0.009612846113925275,
#   0.006272951006948181,
#   0.006605902070833347,
#   0.005126857105983653,
#   0.005858007592199694,
#   0.003854447024475383],
#  [0.03304567330300567,
#   0.017990437630174272,
#   0.01086011589451763,
#   0.009510903150504617,
#   0.008768308271919932,
#   0.004751058694676031,
#   0.005070110092897409,
#   0.00341172062922741,
#   0.0042574841839134675],
#  [0.03320466567744195,
#   0.025521166076559115,
#   0.010685522660736746,
#   0.007172840693268035,
#   0.006849285528301366,
#   0.005020445611424899,
#   0.00500945186559848,
#   0.006288695397562577,
#   0.004578901180264245],
#  [0.03842354938612774,
#   0.012276676222837006,
#   0.011034413113355788,
#   0.009654533362011143,
#   0.008229714547939967,
#   0.0058252928239891704,
#   0.005369027243514391,
#   0.005744819665899928,
#   0.0035615709935351023],
#  [0.043812835063847554,
#   0.015848630896938342,
#   0.010977104631285513,
#   0.01038434579875008,
#   0.007717747128324293,
#   0.008119283852531469,
#   0.005144808592677446,
#   0.0031733257594115374,
#   0.003956083510494699],
#  [0.034781834467606396,
#   0.016993901939018886,
#   0.010026321778935483,
#   0.007500369139452655,
#   0.007338956079328374,
#   0.005120953166472334,
#   0.005356719238017688,
#   0.0031979470676142914,
#   0.005971077933135757],
#  [0.05054151247745509,
#   0.02370669785990934,
#   0.011531073588003414,
#   0.010204473023775862,
#   0.009493927548998223,
#   0.00919310907793246,
#   0.004874296066344133,
#   0.0038587352040526956,
#   0.004155284237531752],
#  [0.032930953937648964,
#   0.015735628242975423,
#   0.014269009102583458,
#   0.008495179084137721,
#   0.007665724944317257,
#   0.005355915060769977,
#   0.004238837955426452,
#   0.0038021018443400835,
#   0.0034084141311917573]]

# %% [markdown]
# ## StateVector

# %%
backend = QasmSimulator(method='statevector')

for x in range(1,20,1):
    print()
arr = []
for nsh in range(1,20,1):
    arr.append([])
    for lp in range(1,10,1):
        nshot=int(round(1000*(nsh)**1.5,0))
        nparam=1000*lp
        fidelity=[]    
        for x in range(nparam):
            qr = QuantumRegister(1)
            cr = ClassicalRegister(1)
            qc = QuantumCircuit(qr, cr)

            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )
            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )

            qc.measure(qr[0],cr[0])
            job = execute(qc, backend, shots=nshot)
            result = job.result()
            count =result.get_counts()

            if '0' in count and '1' in count:
                ratio=count['0']/nshot
            elif '0' in count and '1' not in count:
                ratio=count['0']/nshot
            else:
                ratio=0

            fidelity.append(ratio)   
            #Kullback Leibler divergence
        weights = np.ones_like(fidelity)/float(len(fidelity))            
        P_U_hist=np.histogram(fidelity, bins=bins_list, weights=weights, range=[0, 1])[0];
        #Kullback Leibler divergence
        
        arr[nsh-1].append(sum(rel_entr(P_U_hist, P_harr_hist)))
        print(nshot,'shots per simulation',nparam,'distribution size KL=',sum(rel_entr(P_U_hist, P_harr_hist)))
import sys
import numpy
statevector1=arr
numpy.set_printoptions(threshold=sys.maxsize)
np.savetxt("KLDivg_statevector.txt",statevector1)
# Out:
# 1000 shots per simulation 1000 distribution size KL= 0.04287068603217999
# 1000 shots per simulation 2000 distribution size KL= 0.01414771637344878
# 1000 shots per simulation 3000 distribution size KL= 0.013004117460274255
# 1000 shots per simulation 4000 distribution size KL= 0.010787561104774582
# 1000 shots per simulation 5000 distribution size KL= 0.00791017199446588
# 1000 shots per simulation 6000 distribution size KL= 0.004785621029812685
# 1000 shots per simulation 7000 distribution size KL= 0.006413091929208285
# 1000 shots per simulation 8000 distribution size KL= 0.00590509664591104
# 1000 shots per simulation 9000 distribution size KL= 0.0034778736726820557
# 2828 shots per simulation 1000 distribution size KL= 0.044603251972311485
# 2828 shots per simulation 2000 distribution size KL= 0.0170459702794827
# 2828 shots per simulation 3000 distribution size KL= 0.015792283131241265
# 2828 shots per simulation 4000 distribution size KL= 0.009434541533006498
# 2828 shots per simulation 5000 distribution size KL= 0.007164447948481071
# 2828 shots per simulation 6000 distribution size KL= 0.005363072722903665
# 2828 shots per simulation 7000 distribution size KL= 0.004506117556993646
# 2828 shots per simulation 8000 distribution size KL= 0.006104861624752088
# 2828 shots per simulation 9000 distribution size KL= 0.004881005675324065
# 5196 shots per simulation 1000 distribution size KL= 0.03566761859269829
# 5196 shots per simulation 2000 distribution size KL= 0.018418437342676255
# 5196 shots per simulation 3000 distribution size KL= 0.013486128824364965
# 5196 shots per simulation 4000 distribution size KL= 0.010504743487293362
# 5196 shots per simulation 5000 distribution size KL= 0.009345202378774222
# 5196 shots per simulation 6000 distribution size KL= 0.005238950045369716
# 5196 shots per simulation 7000 distribution size KL= 0.006587843751301442
# 5196 shots per simulation 8000 distribution size KL= 0.003462954328721237
# 5196 shots per simulation 9000 distribution size KL= 0.004089902038423198
# 8000 shots per simulation 1000 distribution size KL= 0.03607811635737038
# 8000 shots per simulation 2000 distribution size KL= 0.0169579748637921
# 8000 shots per simulation 3000 distribution size KL= 0.013350653120388889
# 8000 shots per simulation 4000 distribution size KL= 0.008222578146975114
# 8000 shots per simulation 5000 distribution size KL= 0.008012382576632168
# 8000 shots per simulation 6000 distribution size KL= 0.006161277158623701
# 8000 shots per simulation 7000 distribution size KL= 0.004800957123749852
# 8000 shots per simulation 8000 distribution size KL= 0.005240570485598033
# 8000 shots per simulation 9000 distribution size KL= 0.004546547664574632
# 11180 shots per simulation 1000 distribution size KL= 0.040732713946407845
# 11180 shots per simulation 2000 distribution size KL= 0.02071109396067169
# 11180 shots per simulation 3000 distribution size KL= 0.013421203386704819
# 11180 shots per simulation 4000 distribution size KL= 0.011124067045045911
# 11180 shots per simulation 5000 distribution size KL= 0.008225438263710945
# 11180 shots per simulation 6000 distribution size KL= 0.008131164925954238
# 11180 shots per simulation 7000 distribution size KL= 0.005031253744839882
# 11180 shots per simulation 8000 distribution size KL= 0.004811200260131363
# 11180 shots per simulation 9000 distribution size KL= 0.00399846064623325
# 14697 shots per simulation 1000 distribution size KL= 0.036763835819505146
# 14697 shots per simulation 2000 distribution size KL= 0.014772865496246011
# 14697 shots per simulation 3000 distribution size KL= 0.011190680270691023
# 14697 shots per simulation 4000 distribution size KL= 0.008189777045460934
# 14697 shots per simulation 5000 distribution size KL= 0.006858038982141946
# 14697 shots per simulation 6000 distribution size KL= 0.0051973302092460745
# 14697 shots per simulation 7000 distribution size KL= 0.006435788171785836
# 14697 shots per simulation 8000 distribution size KL= 0.004652384785679673
# 14697 shots per simulation 9000 distribution size KL= 0.00431601275979962
# 18520 shots per simulation 1000 distribution size KL= 0.04427971179556834
# 18520 shots per simulation 2000 distribution size KL= 0.021038038674911
# 18520 shots per simulation 3000 distribution size KL= 0.010394360854945805
# 18520 shots per simulation 4000 distribution size KL= 0.005087597470902092
# 18520 shots per simulation 5000 distribution size KL= 0.00735326054260084
# 18520 shots per simulation 6000 distribution size KL= 0.006350255556368455
# 18520 shots per simulation 7000 distribution size KL= 0.0049167399945588145
# 18520 shots per simulation 8000 distribution size KL= 0.005108186047011857
# 18520 shots per simulation 9000 distribution size KL= 0.0043173078151289394
# 22627 shots per simulation 1000 distribution size KL= 0.04128093336579428
# 22627 shots per simulation 2000 distribution size KL= 0.018600507707012732
# 22627 shots per simulation 3000 distribution size KL= 0.012736324449931023
# 22627 shots per simulation 4000 distribution size KL= 0.009515853366113691
# 22627 shots per simulation 5000 distribution size KL= 0.008737396610774748
# 22627 shots per simulation 6000 distribution size KL= 0.006163097134728247
# 22627 shots per simulation 7000 distribution size KL= 0.004484167619643749
# 22627 shots per simulation 8000 distribution size KL= 0.005300851749927857
# 22627 shots per simulation 9000 distribution size KL= 0.004471205597185628
# 27000 shots per simulation 1000 distribution size KL= 0.03587176116825552
# 27000 shots per simulation 2000 distribution size KL= 0.015159922475138922
# 27000 shots per simulation 3000 distribution size KL= 0.014175283846741122
# 27000 shots per simulation 4000 distribution size KL= 0.008264421362011515
# 27000 shots per simulation 5000 distribution size KL= 0.010637574943581514
# 27000 shots per simulation 6000 distribution size KL= 0.005796016967320245
# 27000 shots per simulation 7000 distribution size KL= 0.003925165146014566
# 27000 shots per simulation 8000 distribution size KL= 0.00460760826033039
# 27000 shots per simulation 9000 distribution size KL= 0.004360591793654355
# 31623 shots per simulation 1000 distribution size KL= 0.044340595731946646
# 31623 shots per simulation 2000 distribution size KL= 0.014015845263820484
# 31623 shots per simulation 3000 distribution size KL= 0.016531731498095528
# 31623 shots per simulation 4000 distribution size KL= 0.010988450377655364
# 31623 shots per simulation 5000 distribution size KL= 0.00589485032520467
# 31623 shots per simulation 6000 distribution size KL= 0.007931185579674063
# 31623 shots per simulation 7000 distribution size KL= 0.004579697813644185
# 31623 shots per simulation 8000 distribution size KL= 0.004251638355092974
# 31623 shots per simulation 9000 distribution size KL= 0.004003458678833299
# 36483 shots per simulation 1000 distribution size KL= 0.029516610726154094
# 36483 shots per simulation 2000 distribution size KL= 0.01692623778212008
# 36483 shots per simulation 3000 distribution size KL= 0.013945401937087409
# 36483 shots per simulation 4000 distribution size KL= 0.00692152095169336
# 36483 shots per simulation 5000 distribution size KL= 0.0064713207543561566
# 36483 shots per simulation 6000 distribution size KL= 0.00824039433949772
# 36483 shots per simulation 7000 distribution size KL= 0.004059409341843751
# 36483 shots per simulation 8000 distribution size KL= 0.0053116755571773625
# 36483 shots per simulation 9000 distribution size KL= 0.003587326289143408
# 41569 shots per simulation 1000 distribution size KL= 0.042037230743114225
# 41569 shots per simulation 2000 distribution size KL= 0.02232816739497635
# 41569 shots per simulation 3000 distribution size KL= 0.012939686117953209
# 41569 shots per simulation 4000 distribution size KL= 0.011566975204271909
# 41569 shots per simulation 5000 distribution size KL= 0.0068379789661883305
# 41569 shots per simulation 6000 distribution size KL= 0.004821208534391372
# 41569 shots per simulation 7000 distribution size KL= 0.005072587433460273
# 41569 shots per simulation 8000 distribution size KL= 0.004531362845619873
# 41569 shots per simulation 9000 distribution size KL= 0.004857502633095763
# 46872 shots per simulation 1000 distribution size KL= 0.04739113764756054
# 46872 shots per simulation 2000 distribution size KL= 0.016778735189903995
# 46872 shots per simulation 3000 distribution size KL= 0.011179296126252965
# 46872 shots per simulation 4000 distribution size KL= 0.008166118107717392
# 46872 shots per simulation 5000 distribution size KL= 0.00716230214304284
# 46872 shots per simulation 6000 distribution size KL= 0.006415164948565989
# 46872 shots per simulation 7000 distribution size KL= 0.004673797775086431
# 46872 shots per simulation 8000 distribution size KL= 0.004856370181748772
# 46872 shots per simulation 9000 distribution size KL= 0.0048313818190834565
# 52383 shots per simulation 1000 distribution size KL= 0.0283733050836924
# 52383 shots per simulation 2000 distribution size KL= 0.01491610151496562
# 52383 shots per simulation 3000 distribution size KL= 0.009945809881899564
# 52383 shots per simulation 4000 distribution size KL= 0.01054853576019752
# 52383 shots per simulation 5000 distribution size KL= 0.008279582312151064
# 52383 shots per simulation 6000 distribution size KL= 0.005188967192955173
# 52383 shots per simulation 7000 distribution size KL= 0.005593021577600019
# 52383 shots per simulation 8000 distribution size KL= 0.0043809855031954345
# 52383 shots per simulation 9000 distribution size KL= 0.004073642351303653
# 58095 shots per simulation 1000 distribution size KL= 0.04654101403420488
# 58095 shots per simulation 2000 distribution size KL= 0.019018190241903613
# 58095 shots per simulation 3000 distribution size KL= 0.013842997520452654
# 58095 shots per simulation 4000 distribution size KL= 0.009090509202401613
# 58095 shots per simulation 5000 distribution size KL= 0.005683240721002181
# 58095 shots per simulation 6000 distribution size KL= 0.005775278977580995
# 58095 shots per simulation 7000 distribution size KL= 0.00547952630172158
# 58095 shots per simulation 8000 distribution size KL= 0.004651572205412511
# 58095 shots per simulation 9000 distribution size KL= 0.005176308891980274
# 64000 shots per simulation 1000 distribution size KL= 0.03540370294967033
# 64000 shots per simulation 2000 distribution size KL= 0.018843871064597093
# 64000 shots per simulation 3000 distribution size KL= 0.01188825775516161
# 64000 shots per simulation 4000 distribution size KL= 0.009610514036325887
# 64000 shots per simulation 5000 distribution size KL= 0.008291005647082064
# 64000 shots per simulation 6000 distribution size KL= 0.006477355722181867
# 64000 shots per simulation 7000 distribution size KL= 0.005903717769684756
# 64000 shots per simulation 8000 distribution size KL= 0.00545728711702406
# 64000 shots per simulation 9000 distribution size KL= 0.004632733202196013
# 70093 shots per simulation 1000 distribution size KL= 0.02648902936571409
# 70093 shots per simulation 2000 distribution size KL= 0.01519053788398844
# 70093 shots per simulation 3000 distribution size KL= 0.01263570948180763
# 70093 shots per simulation 4000 distribution size KL= 0.011972208679014123
# 70093 shots per simulation 5000 distribution size KL= 0.007350214588035183
# 70093 shots per simulation 6000 distribution size KL= 0.007771714481249621
# 70093 shots per simulation 7000 distribution size KL= 0.007659136391731818
# 70093 shots per simulation 8000 distribution size KL= 0.004010180678040769
# 70093 shots per simulation 9000 distribution size KL= 0.0028417090473452163
# 76368 shots per simulation 1000 distribution size KL= 0.04720621851559502
# 76368 shots per simulation 2000 distribution size KL= 0.016429555890706302
# 76368 shots per simulation 3000 distribution size KL= 0.009335124955250072
# 76368 shots per simulation 4000 distribution size KL= 0.010481007453355312
# 76368 shots per simulation 5000 distribution size KL= 0.0070186482621504035
# 76368 shots per simulation 6000 distribution size KL= 0.007547225005093666
# 76368 shots per simulation 7000 distribution size KL= 0.006421567010534702
# 76368 shots per simulation 8000 distribution size KL= 0.0052813251560312
# 76368 shots per simulation 9000 distribution size KL= 0.003466796849138949
# 82819 shots per simulation 1000 distribution size KL= 0.030040369006160837
# 82819 shots per simulation 2000 distribution size KL= 0.01912594946485642
# 82819 shots per simulation 3000 distribution size KL= 0.010856386960658375
# 82819 shots per simulation 4000 distribution size KL= 0.00768115782812563
# 82819 shots per simulation 5000 distribution size KL= 0.007350481863014469
# 82819 shots per simulation 6000 distribution size KL= 0.006411714388120213
# 82819 shots per simulation 7000 distribution size KL= 0.005593015716487699
# 82819 shots per simulation 8000 distribution size KL= 0.004496145078249627
# 82819 shots per simulation 9000 distribution size KL= 0.004408244835283527

# %%
statevector1
# Out:
# [[0.04287068603217999,
#   0.01414771637344878,
#   0.013004117460274255,
#   0.010787561104774582,
#   0.00791017199446588,
#   0.004785621029812685,
#   0.006413091929208285,
#   0.00590509664591104,
#   0.0034778736726820557],
#  [0.044603251972311485,
#   0.0170459702794827,
#   0.015792283131241265,
#   0.009434541533006498,
#   0.007164447948481071,
#   0.005363072722903665,
#   0.004506117556993646,
#   0.006104861624752088,
#   0.004881005675324065],
#  [0.03566761859269829,
#   0.018418437342676255,
#   0.013486128824364965,
#   0.010504743487293362,
#   0.009345202378774222,
#   0.005238950045369716,
#   0.006587843751301442,
#   0.003462954328721237,
#   0.004089902038423198],
#  [0.03607811635737038,
#   0.0169579748637921,
#   0.013350653120388889,
#   0.008222578146975114,
#   0.008012382576632168,
#   0.006161277158623701,
#   0.004800957123749852,
#   0.005240570485598033,
#   0.004546547664574632],
#  [0.040732713946407845,
#   0.02071109396067169,
#   0.013421203386704819,
#   0.011124067045045911,
#   0.008225438263710945,
#   0.008131164925954238,
#   0.005031253744839882,
#   0.004811200260131363,
#   0.00399846064623325],
#  [0.036763835819505146,
#   0.014772865496246011,
#   0.011190680270691023,
#   0.008189777045460934,
#   0.006858038982141946,
#   0.0051973302092460745,
#   0.006435788171785836,
#   0.004652384785679673,
#   0.00431601275979962],
#  [0.04427971179556834,
#   0.021038038674911,
#   0.010394360854945805,
#   0.005087597470902092,
#   0.00735326054260084,
#   0.006350255556368455,
#   0.0049167399945588145,
#   0.005108186047011857,
#   0.0043173078151289394],
#  [0.04128093336579428,
#   0.018600507707012732,
#   0.012736324449931023,
#   0.009515853366113691,
#   0.008737396610774748,
#   0.006163097134728247,
#   0.004484167619643749,
#   0.005300851749927857,
#   0.004471205597185628],
#  [0.03587176116825552,
#   0.015159922475138922,
#   0.014175283846741122,
#   0.008264421362011515,
#   0.010637574943581514,
#   0.005796016967320245,
#   0.003925165146014566,
#   0.00460760826033039,
#   0.004360591793654355],
#  [0.044340595731946646,
#   0.014015845263820484,
#   0.016531731498095528,
#   0.010988450377655364,
#   0.00589485032520467,
#   0.007931185579674063,
#   0.004579697813644185,
#   0.004251638355092974,
#   0.004003458678833299],
#  [0.029516610726154094,
#   0.01692623778212008,
#   0.013945401937087409,
#   0.00692152095169336,
#   0.0064713207543561566,
#   0.00824039433949772,
#   0.004059409341843751,
#   0.0053116755571773625,
#   0.003587326289143408],
#  [0.042037230743114225,
#   0.02232816739497635,
#   0.012939686117953209,
#   0.011566975204271909,
#   0.0068379789661883305,
#   0.004821208534391372,
#   0.005072587433460273,
#   0.004531362845619873,
#   0.004857502633095763],
#  [0.04739113764756054,
#   0.016778735189903995,
#   0.011179296126252965,
#   0.008166118107717392,
#   0.00716230214304284,
#   0.006415164948565989,
#   0.004673797775086431,
#   0.004856370181748772,
#   0.0048313818190834565],
#  [0.0283733050836924,
#   0.01491610151496562,
#   0.009945809881899564,
#   0.01054853576019752,
#   0.008279582312151064,
#   0.005188967192955173,
#   0.005593021577600019,
#   0.0043809855031954345,
#   0.004073642351303653],
#  [0.04654101403420488,
#   0.019018190241903613,
#   0.013842997520452654,
#   0.009090509202401613,
#   0.005683240721002181,
#   0.005775278977580995,
#   0.00547952630172158,
#   0.004651572205412511,
#   0.005176308891980274],
#  [0.03540370294967033,
#   0.018843871064597093,
#   0.01188825775516161,
#   0.009610514036325887,
#   0.008291005647082064,
#   0.006477355722181867,
#   0.005903717769684756,
#   0.00545728711702406,
#   0.004632733202196013],
#  [0.02648902936571409,
#   0.01519053788398844,
#   0.01263570948180763,
#   0.011972208679014123,
#   0.007350214588035183,
#   0.007771714481249621,
#   0.007659136391731818,
#   0.004010180678040769,
#   0.0028417090473452163],
#  [0.04720621851559502,
#   0.016429555890706302,
#   0.009335124955250072,
#   0.010481007453355312,
#   0.0070186482621504035,
#   0.007547225005093666,
#   0.006421567010534702,
#   0.0052813251560312,
#   0.003466796849138949],
#  [0.030040369006160837,
#   0.01912594946485642,
#   0.010856386960658375,
#   0.00768115782812563,
#   0.007350481863014469,
#   0.006411714388120213,
#   0.005593015716487699,
#   0.004496145078249627,
#   0.004408244835283527]]

# %% [markdown]
# ## matrix_product_state

# %%
backend = QasmSimulator(method='matrix_product_state')

for x in range(1,20,1):
    print()
arr = []
for nsh in range(1,20,1):
    arr.append([])
    for lp in range(1,10,1):
        nshot=int(round(1000*(nsh)**1.5,0))
        nparam=1000*lp
        fidelity=[]    
        for x in range(nparam):
            qr = QuantumRegister(1)
            cr = ClassicalRegister(1)
            qc = QuantumCircuit(qr, cr)

            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )
            u13=UnitaryGate(random_unitary(2))
            qc.append(u13, [qr[0]] )

            qc.measure(qr[0],cr[0])
            job = execute(qc, backend, shots=nshot)
            result = job.result()
            count =result.get_counts()

            if '0' in count and '1' in count:
                ratio=count['0']/nshot
            elif '0' in count and '1' not in count:
                ratio=count['0']/nshot
            else:
                ratio=0

            fidelity.append(ratio)   
            #Kullback Leibler divergence
        weights = np.ones_like(fidelity)/float(len(fidelity))            
        P_U_hist=np.histogram(fidelity, bins=bins_list, weights=weights, range=[0, 1])[0];
        #Kullback Leibler divergence
        
        arr[nsh-1].append(sum(rel_entr(P_U_hist, P_harr_hist)))
        print(nshot,'shots per simulation',nparam,'distribution size KL=',sum(rel_entr(P_U_hist, P_harr_hist)))
import sys
import numpy
matrix_product1=arr
numpy.set_printoptions(threshold=sys.maxsize)
np.savetxt("KLDivg_matrix_product1.txt",matrix_product1)
# Out:
# 1000 shots per simulation 1000 distribution size KL= 0.04852502119817211
# 1000 shots per simulation 2000 distribution size KL= 0.011546374804231863
# 1000 shots per simulation 3000 distribution size KL= 0.010125849630433597
# 1000 shots per simulation 4000 distribution size KL= 0.009713780213122705
# 1000 shots per simulation 5000 distribution size KL= 0.009291695177474881
# 1000 shots per simulation 6000 distribution size KL= 0.0049790411031398465
# 1000 shots per simulation 7000 distribution size KL= 0.008359623696496541
# 1000 shots per simulation 8000 distribution size KL= 0.005981514416323768
# 1000 shots per simulation 9000 distribution size KL= 0.004200615739630198
# 2828 shots per simulation 1000 distribution size KL= 0.03582968578977867
# 2828 shots per simulation 2000 distribution size KL= 0.016883637360838942
# 2828 shots per simulation 3000 distribution size KL= 0.012675562708834298
# 2828 shots per simulation 4000 distribution size KL= 0.008138856108815283
# 2828 shots per simulation 5000 distribution size KL= 0.010456378903567279
# 2828 shots per simulation 6000 distribution size KL= 0.005965743995943791
# 2828 shots per simulation 7000 distribution size KL= 0.0043596677376050745
# 2828 shots per simulation 8000 distribution size KL= 0.005451175634472689
# 2828 shots per simulation 9000 distribution size KL= 0.005085934380595612
# 5196 shots per simulation 1000 distribution size KL= 0.031250484055904054
# 5196 shots per simulation 2000 distribution size KL= 0.017913531455624708
# 5196 shots per simulation 3000 distribution size KL= 0.011535994466782573
# 5196 shots per simulation 4000 distribution size KL= 0.010774075903758465
# 5196 shots per simulation 5000 distribution size KL= 0.007250184530028675
# 5196 shots per simulation 6000 distribution size KL= 0.004708037760279228
# 5196 shots per simulation 7000 distribution size KL= 0.0056259460743779705
# 5196 shots per simulation 8000 distribution size KL= 0.0050925892988328055
# 5196 shots per simulation 9000 distribution size KL= 0.004280529211787295
# 8000 shots per simulation 1000 distribution size KL= 0.048656521756021816
# 8000 shots per simulation 2000 distribution size KL= 0.023521543062585838
# 8000 shots per simulation 3000 distribution size KL= 0.013656000725273296
# 8000 shots per simulation 4000 distribution size KL= 0.008967563920489023
# 8000 shots per simulation 5000 distribution size KL= 0.006145102014448462
# 8000 shots per simulation 6000 distribution size KL= 0.004620735843893743
# 8000 shots per simulation 7000 distribution size KL= 0.005691408004170637
# 8000 shots per simulation 8000 distribution size KL= 0.004678480035706051
# 8000 shots per simulation 9000 distribution size KL= 0.0045017348552894
# 11180 shots per simulation 1000 distribution size KL= 0.03663742674703567
# 11180 shots per simulation 2000 distribution size KL= 0.015147398855326583
# 11180 shots per simulation 3000 distribution size KL= 0.013811411953322549
# 11180 shots per simulation 4000 distribution size KL= 0.006885831770329053
# 11180 shots per simulation 5000 distribution size KL= 0.007148440911492363
# 11180 shots per simulation 6000 distribution size KL= 0.005489739650755261
# 11180 shots per simulation 7000 distribution size KL= 0.004737446574430289
# 11180 shots per simulation 8000 distribution size KL= 0.005033385816419186
# 11180 shots per simulation 9000 distribution size KL= 0.0046219011543478265
# 14697 shots per simulation 1000 distribution size KL= 0.03655415721594212
# 14697 shots per simulation 2000 distribution size KL= 0.01937929277618768
# 14697 shots per simulation 3000 distribution size KL= 0.01729072931385209
# 14697 shots per simulation 4000 distribution size KL= 0.006304481843706497
# 14697 shots per simulation 5000 distribution size KL= 0.008443308731830608
# 14697 shots per simulation 6000 distribution size KL= 0.0052801266198197055
# 14697 shots per simulation 7000 distribution size KL= 0.005894472263977283
# 14697 shots per simulation 8000 distribution size KL= 0.004409691982826023
# 14697 shots per simulation 9000 distribution size KL= 0.003565256240875037
# 18520 shots per simulation 1000 distribution size KL= 0.03125106253182807
# 18520 shots per simulation 2000 distribution size KL= 0.013894619453383517
# 18520 shots per simulation 3000 distribution size KL= 0.009501907453865449
# 18520 shots per simulation 4000 distribution size KL= 0.010284016832691624
# 18520 shots per simulation 5000 distribution size KL= 0.008725728865582141
# 18520 shots per simulation 6000 distribution size KL= 0.0057925765012054285
# 18520 shots per simulation 7000 distribution size KL= 0.0036372215407109365
# 18520 shots per simulation 8000 distribution size KL= 0.005744647879243055
# 18520 shots per simulation 9000 distribution size KL= 0.004936008039156759
# 22627 shots per simulation 1000 distribution size KL= 0.037009564615012674
# 22627 shots per simulation 2000 distribution size KL= 0.012963230709866526
# 22627 shots per simulation 3000 distribution size KL= 0.010663803039370515
# 22627 shots per simulation 4000 distribution size KL= 0.008024302411950927
# 22627 shots per simulation 5000 distribution size KL= 0.007498598687352322
# 22627 shots per simulation 6000 distribution size KL= 0.0043673220802651095
# 22627 shots per simulation 7000 distribution size KL= 0.004374751994987557
# 22627 shots per simulation 8000 distribution size KL= 0.0040856748333952565
# 22627 shots per simulation 9000 distribution size KL= 0.0037973828952929476
# 27000 shots per simulation 1000 distribution size KL= 0.0302108544360747
# 27000 shots per simulation 2000 distribution size KL= 0.015026794936907452
# 27000 shots per simulation 3000 distribution size KL= 0.01341624489643059
# 27000 shots per simulation 4000 distribution size KL= 0.008968279744114434
# 27000 shots per simulation 5000 distribution size KL= 0.007043926372911144
# 27000 shots per simulation 6000 distribution size KL= 0.006185268989467007
# 27000 shots per simulation 7000 distribution size KL= 0.005238433463926853
# 27000 shots per simulation 8000 distribution size KL= 0.004189965846352478
# 27000 shots per simulation 9000 distribution size KL= 0.0037255611145041757
# 31623 shots per simulation 1000 distribution size KL= 0.03332326340019359
# 31623 shots per simulation 2000 distribution size KL= 0.017506209997359325
# 31623 shots per simulation 3000 distribution size KL= 0.00957747036495511
# 31623 shots per simulation 4000 distribution size KL= 0.009704102073306853
# 31623 shots per simulation 5000 distribution size KL= 0.00781981259808339
# 31623 shots per simulation 6000 distribution size KL= 0.004778937163479147
# 31623 shots per simulation 7000 distribution size KL= 0.00561629554074293
# 31623 shots per simulation 8000 distribution size KL= 0.004312929101576814
# 31623 shots per simulation 9000 distribution size KL= 0.005017453565460696
# 36483 shots per simulation 1000 distribution size KL= 0.03039888868871424
# 36483 shots per simulation 2000 distribution size KL= 0.0205553719520321
# 36483 shots per simulation 3000 distribution size KL= 0.01639395072117618
# 36483 shots per simulation 4000 distribution size KL= 0.009770615140822048
# 36483 shots per simulation 5000 distribution size KL= 0.0055747255085044235
# 36483 shots per simulation 6000 distribution size KL= 0.006050217871771208
# 36483 shots per simulation 7000 distribution size KL= 0.004376809143972322
# 36483 shots per simulation 8000 distribution size KL= 0.005563785761450553
# 36483 shots per simulation 9000 distribution size KL= 0.003989294797536548
# 41569 shots per simulation 1000 distribution size KL= 0.038120287202997115
# 41569 shots per simulation 2000 distribution size KL= 0.017573602676921735
# 41569 shots per simulation 3000 distribution size KL= 0.01485026567698684
# 41569 shots per simulation 4000 distribution size KL= 0.009723060317873781
# 41569 shots per simulation 5000 distribution size KL= 0.007681497819098904
# 41569 shots per simulation 6000 distribution size KL= 0.004553194288952475
# 41569 shots per simulation 7000 distribution size KL= 0.005207310734209373
# 41569 shots per simulation 8000 distribution size KL= 0.004082729747456592
# 41569 shots per simulation 9000 distribution size KL= 0.003938814285325291
# 46872 shots per simulation 1000 distribution size KL= 0.034144836566336094
# 46872 shots per simulation 2000 distribution size KL= 0.023086127376300437
# 46872 shots per simulation 3000 distribution size KL= 0.011670897860269579
# 46872 shots per simulation 4000 distribution size KL= 0.008945434439232233
# 46872 shots per simulation 5000 distribution size KL= 0.009895765313813202
# 46872 shots per simulation 6000 distribution size KL= 0.00788892524620397
# 46872 shots per simulation 7000 distribution size KL= 0.004991950213106109
# 46872 shots per simulation 8000 distribution size KL= 0.0042898147598781355
# 46872 shots per simulation 9000 distribution size KL= 0.004894651130912123
# 52383 shots per simulation 1000 distribution size KL= 0.02946590425972756
# 52383 shots per simulation 2000 distribution size KL= 0.020821157132333658
# 52383 shots per simulation 3000 distribution size KL= 0.014465622154876514
# 52383 shots per simulation 4000 distribution size KL= 0.00956376343466619
# 52383 shots per simulation 5000 distribution size KL= 0.006983749675199215
# 52383 shots per simulation 6000 distribution size KL= 0.006585640812383732
# 52383 shots per simulation 7000 distribution size KL= 0.00544657440213328
# 52383 shots per simulation 8000 distribution size KL= 0.0037296636840052464
# 52383 shots per simulation 9000 distribution size KL= 0.004938878008185294
# 58095 shots per simulation 1000 distribution size KL= 0.035670334699596455
# 58095 shots per simulation 2000 distribution size KL= 0.02025791145040335
# 58095 shots per simulation 3000 distribution size KL= 0.011740715112078816
# 58095 shots per simulation 4000 distribution size KL= 0.009309403951089971
# 58095 shots per simulation 5000 distribution size KL= 0.008784482401587374
# 58095 shots per simulation 6000 distribution size KL= 0.00462487607837453
# 58095 shots per simulation 7000 distribution size KL= 0.004641809487033407
# 58095 shots per simulation 8000 distribution size KL= 0.004820831888326993
# 58095 shots per simulation 9000 distribution size KL= 0.003571655039247651
# 64000 shots per simulation 1000 distribution size KL= 0.042872876881645636
# 64000 shots per simulation 2000 distribution size KL= 0.01899317561801295
# 64000 shots per simulation 3000 distribution size KL= 0.009836153630635006
# 64000 shots per simulation 4000 distribution size KL= 0.011459831154562217
# 64000 shots per simulation 5000 distribution size KL= 0.006585495281185971
# 64000 shots per simulation 6000 distribution size KL= 0.0051226416376541385
# 64000 shots per simulation 7000 distribution size KL= 0.006769371892501596
# 64000 shots per simulation 8000 distribution size KL= 0.004559882348813326
# 64000 shots per simulation 9000 distribution size KL= 0.003254126865081929
# 70093 shots per simulation 1000 distribution size KL= 0.028693476165406545
# 70093 shots per simulation 2000 distribution size KL= 0.021383377989427278
# 70093 shots per simulation 3000 distribution size KL= 0.009994327233496223
# 70093 shots per simulation 4000 distribution size KL= 0.009218581749194269
# 70093 shots per simulation 5000 distribution size KL= 0.006776468548432977
# 70093 shots per simulation 6000 distribution size KL= 0.00635802839554327
# 70093 shots per simulation 7000 distribution size KL= 0.005130377446189601
# 70093 shots per simulation 8000 distribution size KL= 0.004507028766117452
# 70093 shots per simulation 9000 distribution size KL= 0.003403150176638886
# 76368 shots per simulation 1000 distribution size KL= 0.04289940771906471
# 76368 shots per simulation 2000 distribution size KL= 0.01672757310376199
# 76368 shots per simulation 3000 distribution size KL= 0.013711308289640923
# 76368 shots per simulation 4000 distribution size KL= 0.009461955649826305
# 76368 shots per simulation 5000 distribution size KL= 0.010119374536108216
# 76368 shots per simulation 6000 distribution size KL= 0.005856731994898489
# 76368 shots per simulation 7000 distribution size KL= 0.005372212536739038
# 76368 shots per simulation 8000 distribution size KL= 0.003828284466544592
# 76368 shots per simulation 9000 distribution size KL= 0.003368077469631206
# 82819 shots per simulation 1000 distribution size KL= 0.04306253385862791
# 82819 shots per simulation 2000 distribution size KL= 0.01856795009028202
# 82819 shots per simulation 3000 distribution size KL= 0.016702927953526153
# 82819 shots per simulation 4000 distribution size KL= 0.00893588395662572
# 82819 shots per simulation 5000 distribution size KL= 0.007447118032367389
# 82819 shots per simulation 6000 distribution size KL= 0.007167868395088207
# 82819 shots per simulation 7000 distribution size KL= 0.005601389795856881
# 82819 shots per simulation 8000 distribution size KL= 0.005925110390018221
# 82819 shots per simulation 9000 distribution size KL= 0.0032781563464686406

# %%
matrix_product1
# Out:
# [[0.04852502119817211,
#   0.011546374804231863,
#   0.010125849630433597,
#   0.009713780213122705,
#   0.009291695177474881,
#   0.0049790411031398465,
#   0.008359623696496541,
#   0.005981514416323768,
#   0.004200615739630198],
#  [0.03582968578977867,
#   0.016883637360838942,
#   0.012675562708834298,
#   0.008138856108815283,
#   0.010456378903567279,
#   0.005965743995943791,
#   0.0043596677376050745,
#   0.005451175634472689,
#   0.005085934380595612],
#  [0.031250484055904054,
#   0.017913531455624708,
#   0.011535994466782573,
#   0.010774075903758465,
#   0.007250184530028675,
#   0.004708037760279228,
#   0.0056259460743779705,
#   0.0050925892988328055,
#   0.004280529211787295],
#  [0.048656521756021816,
#   0.023521543062585838,
#   0.013656000725273296,
#   0.008967563920489023,
#   0.006145102014448462,
#   0.004620735843893743,
#   0.005691408004170637,
#   0.004678480035706051,
#   0.0045017348552894],
#  [0.03663742674703567,
#   0.015147398855326583,
#   0.013811411953322549,
#   0.006885831770329053,
#   0.007148440911492363,
#   0.005489739650755261,
#   0.004737446574430289,
#   0.005033385816419186,
#   0.0046219011543478265],
#  [0.03655415721594212,
#   0.01937929277618768,
#   0.01729072931385209,
#   0.006304481843706497,
#   0.008443308731830608,
#   0.0052801266198197055,
#   0.005894472263977283,
#   0.004409691982826023,
#   0.003565256240875037],
#  [0.03125106253182807,
#   0.013894619453383517,
#   0.009501907453865449,
#   0.010284016832691624,
#   0.008725728865582141,
#   0.0057925765012054285,
#   0.0036372215407109365,
#   0.005744647879243055,
#   0.004936008039156759],
#  [0.037009564615012674,
#   0.012963230709866526,
#   0.010663803039370515,
#   0.008024302411950927,
#   0.007498598687352322,
#   0.0043673220802651095,
#   0.004374751994987557,
#   0.0040856748333952565,
#   0.0037973828952929476],
#  [0.0302108544360747,
#   0.015026794936907452,
#   0.01341624489643059,
#   0.008968279744114434,
#   0.007043926372911144,
#   0.006185268989467007,
#   0.005238433463926853,
#   0.004189965846352478,
#   0.0037255611145041757],
#  [0.03332326340019359,
#   0.017506209997359325,
#   0.00957747036495511,
#   0.009704102073306853,
#   0.00781981259808339,
#   0.004778937163479147,
#   0.00561629554074293,
#   0.004312929101576814,
#   0.005017453565460696],
#  [0.03039888868871424,
#   0.0205553719520321,
#   0.01639395072117618,
#   0.009770615140822048,
#   0.0055747255085044235,
#   0.006050217871771208,
#   0.004376809143972322,
#   0.005563785761450553,
#   0.003989294797536548],
#  [0.038120287202997115,
#   0.017573602676921735,
#   0.01485026567698684,
#   0.009723060317873781,
#   0.007681497819098904,
#   0.004553194288952475,
#   0.005207310734209373,
#   0.004082729747456592,
#   0.003938814285325291],
#  [0.034144836566336094,
#   0.023086127376300437,
#   0.011670897860269579,
#   0.008945434439232233,
#   0.009895765313813202,
#   0.00788892524620397,
#   0.004991950213106109,
#   0.0042898147598781355,
#   0.004894651130912123],
#  [0.02946590425972756,
#   0.020821157132333658,
#   0.014465622154876514,
#   0.00956376343466619,
#   0.006983749675199215,
#   0.006585640812383732,
#   0.00544657440213328,
#   0.0037296636840052464,
#   0.004938878008185294],
#  [0.035670334699596455,
#   0.02025791145040335,
#   0.011740715112078816,
#   0.009309403951089971,
#   0.008784482401587374,
#   0.00462487607837453,
#   0.004641809487033407,
#   0.004820831888326993,
#   0.003571655039247651],
#  [0.042872876881645636,
#   0.01899317561801295,
#   0.009836153630635006,
#   0.011459831154562217,
#   0.006585495281185971,
#   0.0051226416376541385,
#   0.006769371892501596,
#   0.004559882348813326,
#   0.003254126865081929],
#  [0.028693476165406545,
#   0.021383377989427278,
#   0.009994327233496223,
#   0.009218581749194269,
#   0.006776468548432977,
#   0.00635802839554327,
#   0.005130377446189601,
#   0.004507028766117452,
#   0.003403150176638886],
#  [0.04289940771906471,
#   0.01672757310376199,
#   0.013711308289640923,
#   0.009461955649826305,
#   0.010119374536108216,
#   0.005856731994898489,
#   0.005372212536739038,
#   0.003828284466544592,
#   0.003368077469631206],
#  [0.04306253385862791,
#   0.01856795009028202,
#   0.016702927953526153,
#   0.00893588395662572,
#   0.007447118032367389,
#   0.007167868395088207,
#   0.005601389795856881,
#   0.005925110390018221,
#   0.0032781563464686406]]

# %%
def plotdata(i,data):
    klll=np.transpose(data)
    x=[];
    y=[];
    for nsh in range(0,9,1):
        x.append(int(round(1000*(nsh)**1.5,0)))
        y.append(klll[nsh][i])
    return [x,y]

# %% [markdown]
# ## QASM simulator

# %%
#loading dataset
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20, 5))
datalist=[density_mat,statevector1,matrix_product1,qasm]
datalistn=['density_mat','statevector','matrix_product','qasm']
indx=0;
for indx in range(4):
    data=datalist[indx];
    axes[indx].plot(plotdata(0,data)[0],plotdata(0,data)[1], color='red', label='npram=1000');
    axes[indx].plot(plotdata(1,data)[0],plotdata(1,data)[1], color='blue', label='npram=2000');
    axes[indx].plot(plotdata(2,data)[0],plotdata(2,data)[1], color='black', label='npram=3000');
    axes[indx].plot(plotdata(3,data)[0],plotdata(3,data)[1], color='green', label='npram=4000');
    axes[indx].plot(plotdata(4,data)[0],plotdata(4,data)[1], color='purple',  label='npram=5000');
    axes[indx].plot(plotdata(5,data)[0],plotdata(5,data)[1], color='gray',  label='npram=6000');
    axes[indx].plot(plotdata(6,data)[0],plotdata(6,data)[1], color='black',  label='npram=7000');
    axes[indx].plot(plotdata(7,data)[0],plotdata(7,data)[1], color='yellow',  label='npram=8000');
    axes[indx].plot(plotdata(8,data)[0],plotdata(8,data)[1], color='pink',  label='npram=9000');

    axes[indx].set_ylim([0.003, 0.05])
    axes[indx].legend(loc='upper right')
    axes[indx].set_title(datalistn[indx])
    axes[indx].set_yscale('log',base=10) 
    axes[indx].set_ylabel('Expressibility')

# Create names on the x axis

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20, 5))
indx=0
for indx in range(4):
    data=density_mat;
    axes[indx].plot(plotdata(indx,data)[0],plotdata(indx,data)[1], color='red', label='density_mat');
    data=statevector1;
    axes[indx].plot(plotdata(indx,data)[0],plotdata(indx,data)[1], color='blue', label='statevector');
    data=matrix_product1;
    axes[indx].plot(plotdata(indx,data)[0],plotdata(indx,data)[1], color='green', label='matrix_product1');
    data=qasm;
    axes[indx].plot(plotdata(indx,data)[0],plotdata(indx,data)[1], color='pink', label='qasm');
    axes[indx].set_title('nparam='+str(indx*1000))
    axes[indx].set_yscale('log',base=10) 
    axes[indx].set_ylim([0.003, 0.05])
    axes[indx].set_ylabel('Expressibility')
    axes[indx].legend(['density_mat','statevector','matrix_product1','qasm'])
    axes[indx].set_xlabel('iteration')

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20, 5))
indx=0
for indx1 in range(4,8,1):
    indx=indx1-4
    data=density_mat;
    axes[indx].plot(plotdata(indx1,data)[0],plotdata(indx1,data)[1], color='red', label='density_mat');
    data=statevector1;
    axes[indx].plot(plotdata(indx1,data)[0],plotdata(indx1,data)[1], color='blue', label='statevector');
    data=matrix_product1;
    axes[indx].plot(plotdata(indx1,data)[0],plotdata(indx1,data)[1], color='green', label='matrix_product1');
    data=qasm;
    axes[indx].plot(plotdata(indx1,data)[0],plotdata(indx1,data)[1], color='pink', label='qasm');
    axes[indx].set_title('nparam='+str(indx1*1000))
    axes[indx].set_yscale('log',base=10) 
    axes[indx].set_ylabel('Expressibility')
    axes[indx].set_ylim([0.003, 0.05])
    axes[indx].legend(['density_mat','statevector','matrix_product1','qasm'])
    axes[indx].set_xlabel('iteration')
