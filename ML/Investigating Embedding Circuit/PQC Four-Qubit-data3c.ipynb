# %%
import numpy as np
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

data0Path = r'../../dataset/data3c.txt'
data0Label = r'../../dataset/data3clabel.txt'

dataCoords = np.loadtxt(data0Path)
dataLabels = np.loadtxt(data0Label)

# %%
# Make a data structure which is easier to work with
# for shuffling. 
# Also, notice we change the data labels from {0, 1} to {-1, +1}
data = list(zip(dataCoords, 2*dataLabels-1))
shuffled_data = shuffle(data)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(np.ravel(dataCoords[np.where(dataLabels == 0)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 0)])[1::2], ls='', marker='o')

ax.plot(np.ravel(dataCoords[np.where(dataLabels == 1)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 1)])[1::2], ls='', marker='o')

# %%
from IPython.display import Image

# %% [markdown]
# # Loss function Two-Qubit
#
# Loss is calculated with a simple two-qubit gate. First, the data is embedded into Rx rotation with pi/4 rotation of Ry and Rz. The parameterized quantum circuit is placed after the embedding. We used same structure of the circuit1 from the paper to check the convergence.

# %%
from circuits import *
from qiskit.circuit import Parameter

#circuit 1
qr = QuantumRegister(4)
qc = QuantumCircuit(qr)

theta=[]
for i in range(62):
    theta.append((Parameter('θ'+str(i))))
qc=circuit11(qc,qr,theta,1,0)
qc.draw('mpl')

# %%
#load the simulation functcions from the quantumcircuit.py file

from quantumcircuit import *

#location,label,param,[circuit#,layer]
loss_qubitF([0.5,0.5],-1,[0,0,0,-5,0,0,0,0],[0,1])
# Out:
# 0

# %% [markdown]
# ## [SPSA method](https://en.wikipedia.org/wiki/Simultaneous_perturbation_stochastic_approximation)
#
# SPSA is an algorithm used in numerical optimization.
#
# Consider a loss function $L(\mathbf{x})$. In order to optimize $L$, SPSA iteratively optimizes the parameters of the loss function according to the following update rule:
#
# $$\mathbf{y}_{n+1} = \mathbf{y}_{n} - a_{n}\widehat{\Delta L}_{n}(\mathbf{y}_{n}),$$
#
# where $\widehat{\Delta L}_{n}(\mathbf{y}_{n}))$ is an estimate of the gradient at $\mathbf{y}_{n}$.
#
# How SPSA calculates that gradient is by using a finite-difference rule on random perturbations of component of the parameter vector.
#     $$\left( \widehat{\Delta L}_{n}(\mathbf{y}_{n}))\right)_{j} = \frac{L(\mathbf{y}_{n} + c_{n}\boldsymbol{\Delta}_{n}) - L(\mathbf{y}_{n} - c_{n}\boldsymbol{\Delta}_{n}) }{c_{n}\left(\boldsymbol{\Delta}_{n}\right)_{j}}$$
#
# That is at each iteration, SPSA generates a random perturbation $\boldsymbol{\Delta}_{n}$, and does a finite-difference rule with that perturbation.
#
# In order for the algorithm to converge, the random perturbation $\boldsymbol{\Delta}_{n}$ and finite-difference coefficients $c_{n}$ must satisfy certain properties (see the Wikipedia article linked to in the title). Importantly $c_{n}$ must tend to 0 as $n$ increases, and the size of the random fluctuations $\boldsymbol{\Delta}_{n}$ must also be bounded.
#
# According to the wikipedia article, the coefficients $a_{n}$ and $c_{n}$ should look something like
#
# $$c_{n} = \frac{c}{n^\gamma}~~\text{and}~~a_{n} = \frac{a}{n}.$$

# %%
#load the SPSA optimizer from the optimizer.py file
from optimizer import *

# %% [markdown]
# # Test the convergence of 100 data point
#
# To have sanity check, we take 100 data and run the optimization.

# %% [markdown]
# # 0.1

# %%
c = 1
a = 1
aparam=0.1*pi

# Do the updates
lossList = []
coeffsList = []
paramsList = []
accuracyList = []

np.random.seed(2)
currentParams = pi*np.random.uniform(size=8)
for j in range(50):      
    
    cj = c/(j+1)**(1/3)
    aj = a/(j+1)

    
    # Grab a subset of the data for minibatching
    #np.random.seed(j)
    np.random.seed(2)
    #data_ixs = np.random.choice(len(shuffled_data), size=len(shuffled_data))
    data_ixs = np.random.choice(len(data), size=100)
    
    # Evaluate the loss over that subset
    # We include a regularization term at the end 
    L = lambda x: np.sum([loss_qubitF(aparam*data[j][0],aparam*data[j][1],x,[0,1]) for j in data_ixs])/len(data_ixs) 
    
    lossList.append(L(currentParams))
    coeffsList.append((cj, aj))
    paramsList.append(currentParams)
    accuracyList.append(np.sum([predict_qubitF(data[j][0],currentParams,[0,1]) ==data[j][1] for j in data_ixs])/len(data_ixs))
    print(j,"th iteration L=",lossList[-1],"Accuracy =",accuracyList[-1])
    currentParams = SPSA_update(L, currentParams, aj, cj)
# Out:
# 0 th iteration L= 0.9748672587712817 Accuracy = 0.49
# 1 th iteration L= 0.9748672587712817 Accuracy = 0.46
# 2 th iteration L= 0.968584073464102 Accuracy = 0.48
# 3 th iteration L= 0.9748672587712817 Accuracy = 0.49
# 4 th iteration L= 0.9748672587712817 Accuracy = 0.45
# 5 th iteration L= 0.9748672587712817 Accuracy = 0.45
# 6 th iteration L= 0.9748672587712817 Accuracy = 0.46
# 7 th iteration L= 0.9748672587712817 Accuracy = 0.44
# 8 th iteration L= 0.9748672587712817 Accuracy = 0.45
# 9 th iteration L= 0.9748672587712817 Accuracy = 0.44
# 10 th iteration L= 0.9748672587712817 Accuracy = 0.47
# 11 th iteration L= 0.9748672587712817 Accuracy = 0.47
# 12 th iteration L= 0.9748672587712817 Accuracy = 0.45
# 13 th iteration L= 0.9748672587712817 Accuracy = 0.4
# 14 th iteration L= 0.9748672587712817 Accuracy = 0.48
# 15 th iteration L= 0.9748672587712817 Accuracy = 0.5
# 16 th iteration L= 0.9748672587712817 Accuracy = 0.48
# 17 th iteration L= 0.9748672587712817 Accuracy = 0.46
# 18 th iteration L= 0.9748672587712817 Accuracy = 0.48
# 19 th iteration L= 0.9748672587712817 Accuracy = 0.47
# 20 th iteration L= 0.9748672587712817 Accuracy = 0.47
# 21 th iteration L= 0.9748672587712817 Accuracy = 0.48
# 22 th iteration L= 0.9748672587712817 Accuracy = 0.46
# 23 th iteration L= 0.9748672587712817 Accuracy = 0.47
# 24 th iteration L= 0.9748672587712817 Accuracy = 0.49
# 25 th iteration L= 0.9748672587712817 Accuracy = 0.47
# 26 th iteration L= 0.9748672587712817 Accuracy = 0.45
# 27 th iteration L= 0.9748672587712817 Accuracy = 0.5
# 28 th iteration L= 0.9748672587712817 Accuracy = 0.46
# 29 th iteration L= 0.9748672587712817 Accuracy = 0.48
# 30 th iteration L= 0.9748672587712817 Accuracy = 0.47
# 31 th iteration L= 0.9748672587712817 Accuracy = 0.49
# 32 th iteration L= 0.9748672587712817 Accuracy = 0.48
# 33 th iteration L= 0.9748672587712817 Accuracy = 0.5
# 34 th iteration L= 0.9748672587712817 Accuracy = 0.41
# 35 th iteration L= 0.9748672587712817 Accuracy = 0.51
# 36 th iteration L= 0.9748672587712817 Accuracy = 0.46
# 37 th iteration L= 0.9748672587712817 Accuracy = 0.45
# 38 th iteration L= 0.9748672587712817 Accuracy = 0.47
# 39 th iteration L= 0.9748672587712817 Accuracy = 0.48
# 40 th iteration L= 0.9748672587712817 Accuracy = 0.55
# 41 th iteration L= 0.9748672587712817 Accuracy = 0.52
# 42 th iteration L= 0.9748672587712817 Accuracy = 0.51
# 43 th iteration L= 0.9748672587712817 Accuracy = 0.46
# 44 th iteration L= 0.9748672587712817 Accuracy = 0.48
# 45 th iteration L= 0.9748672587712817 Accuracy = 0.46
# 46 th iteration L= 0.9748672587712817 Accuracy = 0.44
# 47 th iteration L= 0.9748672587712817 Accuracy = 0.51
# 48 th iteration L= 0.9748672587712817 Accuracy = 0.47
# 49 th iteration L= 0.9748672587712817 Accuracy = 0.54

# %%
fig = plt.figure(figsize=(15, 10))

ax = fig.add_subplot(2, 2, 1)
ax.plot(lossList)
ax.set_title('Loss function\nStart {0} Finish {1}'.format(np.round(lossList[0], 3), np.round(lossList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 2)
ax.plot(accuracyList)
ax.set_title('Classification accuracy \nStart {0} Finish {1}'.format(np.round(accuracyList[0], 3), np.round(accuracyList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 3)
ax.plot([c[0] for c in coeffsList], label='a')
ax.plot([c[1] for c in coeffsList], label='c')
ax.legend(loc=0)
ax.set_title('Update coefficients')

ax = fig.add_subplot(2, 2, 4)
for j in range(4):
    ax.plot([X[j] for X in paramsList], label='x{0}'.format(j))
ax.legend(loc=0)
ax.set_title('Parameter values')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(np.ravel(dataCoords[np.where(dataLabels == 0)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 0)])[1::2], ls='', marker='o')

ax.plot(np.ravel(dataCoords[np.where(dataLabels == 1)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 1)])[1::2], ls='', marker='o')

X = np.linspace(0, 1, num=20)
Z = np.zeros((len(X), len(X)))

# Contour map
for j in range(len(X)):
    for k in range(len(X)):
        # Fill Z with the labels (numerical values)
        # the inner loop goes over the columns of Z,
        # which corresponds to sweeping x-values
        # Therefore, the role of j,k is flipped in the signature
        Z[j, k] = predict_qubitF( np.array([X[k], X[j]]),currentParams,[0,1])
        
ax.contourf(X, X, Z, cmap='bwr', levels=30)

# %% [markdown]
# # 0.5

# %%
c = 1
a = 1
aparam=0.5*pi

# Do the updates
lossList = []
coeffsList = []
paramsList = []
accuracyList = []

np.random.seed(2)
currentParams = pi*np.random.uniform(size=8)
for j in range(50):      
    
    cj = c/(j+1)**(1/3)
    aj = a/(j+1)

    
    # Grab a subset of the data for minibatching
    #np.random.seed(j)
    np.random.seed(2)
    #data_ixs = np.random.choice(len(shuffled_data), size=len(shuffled_data))
    data_ixs = np.random.choice(len(data), size=100)
    
    # Evaluate the loss over that subset
    # We include a regularization term at the end 
    L = lambda x: np.sum([loss_qubitF(aparam*data[j][0],aparam*data[j][1],x,[0,1]) for j in data_ixs])/len(data_ixs) 
    
    lossList.append(L(currentParams))
    coeffsList.append((cj, aj))
    paramsList.append(currentParams)
    accuracyList.append(np.sum([predict_qubitF(data[j][0],currentParams,[0,1]) ==data[j][1] for j in data_ixs])/len(data_ixs))
    print(j,"th iteration L=",lossList[-1],"Accuracy =",accuracyList[-1])
    currentParams = SPSA_update(L, currentParams, aj, cj)
# Out:
# 0 th iteration L= 1.7507963267948967 Accuracy = 0.46
# 1 th iteration L= 1.7107963267948967 Accuracy = 0.48
# 2 th iteration L= 1.6907963267948964 Accuracy = 0.54
# 3 th iteration L= 1.750796326794897 Accuracy = 0.44
# 4 th iteration L= 1.790796326794897 Accuracy = 0.47
# 5 th iteration L= 1.810796326794897 Accuracy = 0.47
# 6 th iteration L= 1.790796326794897 Accuracy = 0.51
# 7 th iteration L= 1.790796326794897 Accuracy = 0.49
# 8 th iteration L= 1.790796326794897 Accuracy = 0.53
# 9 th iteration L= 1.770796326794897 Accuracy = 0.49
# 10 th iteration L= 1.810796326794897 Accuracy = 0.48
# 11 th iteration L= 1.790796326794897 Accuracy = 0.5
# 12 th iteration L= 1.810796326794897 Accuracy = 0.5
# 13 th iteration L= 1.750796326794897 Accuracy = 0.44
# 14 th iteration L= 1.810796326794897 Accuracy = 0.48
# 15 th iteration L= 1.750796326794897 Accuracy = 0.51
# 16 th iteration L= 1.770796326794897 Accuracy = 0.38
# 17 th iteration L= 1.750796326794897 Accuracy = 0.54
# 18 th iteration L= 1.750796326794897 Accuracy = 0.52
# 19 th iteration L= 1.750796326794897 Accuracy = 0.49
# 20 th iteration L= 1.750796326794897 Accuracy = 0.51
# 21 th iteration L= 1.7507963267948963 Accuracy = 0.51
# 22 th iteration L= 1.790796326794897 Accuracy = 0.51
# 23 th iteration L= 1.770796326794897 Accuracy = 0.5
# 24 th iteration L= 1.6907963267948967 Accuracy = 0.42
# 25 th iteration L= 1.7307963267948967 Accuracy = 0.47
# 26 th iteration L= 1.7107963267948967 Accuracy = 0.45
# 27 th iteration L= 1.6907963267948967 Accuracy = 0.49
# 28 th iteration L= 1.7307963267948967 Accuracy = 0.48
# 29 th iteration L= 1.7107963267948967 Accuracy = 0.49
# 30 th iteration L= 1.7707963267948967 Accuracy = 0.45
# 31 th iteration L= 1.7707963267948967 Accuracy = 0.47
# 32 th iteration L= 1.7307963267948967 Accuracy = 0.49
# 33 th iteration L= 1.7307963267948967 Accuracy = 0.52
# 34 th iteration L= 1.7107963267948967 Accuracy = 0.5
# 35 th iteration L= 1.6907963267948967 Accuracy = 0.48
# 36 th iteration L= 1.6907963267948967 Accuracy = 0.47
# 37 th iteration L= 1.7307963267948967 Accuracy = 0.5
# 38 th iteration L= 1.7107963267948967 Accuracy = 0.49
# 39 th iteration L= 1.6707963267948966 Accuracy = 0.48
# 40 th iteration L= 1.6907963267948967 Accuracy = 0.49
# 41 th iteration L= 1.6707963267948966 Accuracy = 0.46
# 42 th iteration L= 1.6307963267948966 Accuracy = 0.5
# 43 th iteration L= 1.6507963267948966 Accuracy = 0.41
# 44 th iteration L= 1.6907963267948967 Accuracy = 0.45
# 45 th iteration L= 1.6707963267948966 Accuracy = 0.49
# 46 th iteration L= 1.6707963267948966 Accuracy = 0.48
# 47 th iteration L= 1.6707963267948966 Accuracy = 0.47
# 48 th iteration L= 1.7107963267948967 Accuracy = 0.46
# 49 th iteration L= 1.7107963267948967 Accuracy = 0.46

# %%
fig = plt.figure(figsize=(15, 10))

ax = fig.add_subplot(2, 2, 1)
ax.plot(lossList)
ax.set_title('Loss function\nStart {0} Finish {1}'.format(np.round(lossList[0], 3), np.round(lossList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 2)
ax.plot(accuracyList)
ax.set_title('Classification accuracy \nStart {0} Finish {1}'.format(np.round(accuracyList[0], 3), np.round(accuracyList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 3)
ax.plot([c[0] for c in coeffsList], label='a')
ax.plot([c[1] for c in coeffsList], label='c')
ax.legend(loc=0)
ax.set_title('Update coefficients')

ax = fig.add_subplot(2, 2, 4)
for j in range(4):
    ax.plot([X[j] for X in paramsList], label='x{0}'.format(j))
ax.legend(loc=0)
ax.set_title('Parameter values')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(np.ravel(dataCoords[np.where(dataLabels == 0)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 0)])[1::2], ls='', marker='o')

ax.plot(np.ravel(dataCoords[np.where(dataLabels == 1)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 1)])[1::2], ls='', marker='o')

X = np.linspace(0, 1, num=20)
Z = np.zeros((len(X), len(X)))

# Contour map
for j in range(len(X)):
    for k in range(len(X)):
        # Fill Z with the labels (numerical values)
        # the inner loop goes over the columns of Z,
        # which corresponds to sweeping x-values
        # Therefore, the role of j,k is flipped in the signature
        Z[j, k] = predict_qubitF( np.array([X[k], X[j]]),currentParams,[0,1])
        
ax.contourf(X, X, Z, cmap='bwr', levels=30)

# %% [markdown]
# # 1.0

# %%
c = 1
a = 1
aparam=1.0*pi

# Do the updates
lossList = []
coeffsList = []
paramsList = []
accuracyList = []

np.random.seed(2)
currentParams = pi*np.random.uniform(size=8)
for j in range(50):    
    
    cj = c/(j+1)**(1/3)
    aj = a/(j+1)

    
    # Grab a subset of the data for minibatching
    #np.random.seed(j)
    np.random.seed(2)
    #data_ixs = np.random.choice(len(shuffled_data), size=len(shuffled_data))
    data_ixs = np.random.choice(len(data), size=100)
    
    # Evaluate the loss over that subset
    # We include a regularization term at the end 
    L = lambda x: np.sum([loss_qubitF(aparam*data[j][0],aparam*data[j][1],x,[0,1]) for j in data_ixs])/len(data_ixs) 
    
    lossList.append(L(currentParams))
    coeffsList.append((cj, aj))
    paramsList.append(currentParams)
    accuracyList.append(np.sum([predict_qubitF(data[j][0],currentParams,[0,1]) ==data[j][1] for j in data_ixs])/len(data_ixs))
    print(j,"th iteration L=",lossList[-1],"Accuracy =",accuracyList[-1])
    currentParams = SPSA_update(L, currentParams, aj, cj)
# Out:
# 0 th iteration L= 3.0415926535897926 Accuracy = 0.49
# 1 th iteration L= 2.9415926535897925 Accuracy = 0.45
# 2 th iteration L= 2.9815926535897925 Accuracy = 0.44
# 3 th iteration L= 3.0415926535897926 Accuracy = 0.5
# 4 th iteration L= 3.0015926535897925 Accuracy = 0.43
# 5 th iteration L= 3.0215926535897926 Accuracy = 0.49
# 6 th iteration L= 3.0015926535897925 Accuracy = 0.51
# 7 th iteration L= 3.0215926535897926 Accuracy = 0.47
# 8 th iteration L= 3.0015926535897925 Accuracy = 0.48
# 9 th iteration L= 3.0015926535897925 Accuracy = 0.47
# 10 th iteration L= 3.0215926535897926 Accuracy = 0.47
# 11 th iteration L= 3.0415926535897926 Accuracy = 0.43
# 12 th iteration L= 2.9815926535897925 Accuracy = 0.5
# 13 th iteration L= 3.0415926535897926 Accuracy = 0.48
# 14 th iteration L= 3.0615926535897926 Accuracy = 0.52
# 15 th iteration L= 3.0415926535897926 Accuracy = 0.47
# 16 th iteration L= 3.0015926535897925 Accuracy = 0.48
# 17 th iteration L= 3.0215926535897926 Accuracy = 0.48
# 18 th iteration L= 2.9815926535897925 Accuracy = 0.45
# 19 th iteration L= 3.0015926535897925 Accuracy = 0.48
# 20 th iteration L= 3.0215926535897926 Accuracy = 0.49
# 21 th iteration L= 2.9815926535897925 Accuracy = 0.47
# 22 th iteration L= 3.0215926535897926 Accuracy = 0.44
# 23 th iteration L= 3.0015926535897925 Accuracy = 0.48

# %%
fig = plt.figure(figsize=(15, 10))

ax = fig.add_subplot(2, 2, 1)
ax.plot(lossList)
ax.set_title('Loss function\nStart {0} Finish {1}'.format(np.round(lossList[0], 3), np.round(lossList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 2)
ax.plot(accuracyList)
ax.set_title('Classification accuracy \nStart {0} Finish {1}'.format(np.round(accuracyList[0], 3), np.round(accuracyList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 3)
ax.plot([c[0] for c in coeffsList], label='a')
ax.plot([c[1] for c in coeffsList], label='c')
ax.legend(loc=0)
ax.set_title('Update coefficients')

ax = fig.add_subplot(2, 2, 4)
for j in range(4):
    ax.plot([X[j] for X in paramsList], label='x{0}'.format(j))
ax.legend(loc=0)
ax.set_title('Parameter values')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(np.ravel(dataCoords[np.where(dataLabels == 0)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 0)])[1::2], ls='', marker='o')

ax.plot(np.ravel(dataCoords[np.where(dataLabels == 1)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 1)])[1::2], ls='', marker='o')

X = np.linspace(0, 1, num=20)
Z = np.zeros((len(X), len(X)))

# Contour map
for j in range(len(X)):
    for k in range(len(X)):
        # Fill Z with the labels (numerical values)
        # the inner loop goes over the columns of Z,
        # which corresponds to sweeping x-values
        # Therefore, the role of j,k is flipped in the signature
        Z[j, k] = predict_qubitF( np.array([X[k], X[j]]),currentParams,[0,1])
        
ax.contourf(X, X, Z, cmap='bwr', levels=30)

# %% [markdown]
# # 2.0

# %%
c = 1
a = 1
aparam=2.0*pi

# Do the updates
lossList = []
coeffsList = []
paramsList = []
accuracyList = []

np.random.seed(2)
currentParams = pi*np.random.uniform(size=8)
for j in range(50):    
    
    cj = c/(j+1)**(1/3)
    aj = a/(j+1)

    
    # Grab a subset of the data for minibatching
    #np.random.seed(j)
    np.random.seed(2)
    #data_ixs = np.random.choice(len(shuffled_data), size=len(shuffled_data))
    data_ixs = np.random.choice(len(data), size=100)
    
    # Evaluate the loss over that subset
    # We include a regularization term at the end 
    L = lambda x: np.sum([loss_qubitF(aparam*data[j][0],aparam*data[j][1],x,[0,1]) for j in data_ixs])/len(data_ixs) 
    
    lossList.append(L(currentParams))
    coeffsList.append((cj, aj))
    paramsList.append(currentParams)
    accuracyList.append(np.sum([predict_qubitF(data[j][0],currentParams,[0,1]) ==data[j][1] for j in data_ixs])/len(data_ixs))
    print(j,"th iteration L=",lossList[-1],"Accuracy =",accuracyList[-1])
    currentParams = SPSA_update(L, currentParams, aj, cj)

# %%
fig = plt.figure(figsize=(15, 10))

ax = fig.add_subplot(2, 2, 1)
ax.plot(lossList)
ax.set_title('Loss function\nStart {0} Finish {1}'.format(np.round(lossList[0], 3), np.round(lossList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 2)
ax.plot(accuracyList)
ax.set_title('Classification accuracy \nStart {0} Finish {1}'.format(np.round(accuracyList[0], 3), np.round(accuracyList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 3)
ax.plot([c[0] for c in coeffsList], label='a')
ax.plot([c[1] for c in coeffsList], label='c')
ax.legend(loc=0)
ax.set_title('Update coefficients')

ax = fig.add_subplot(2, 2, 4)
for j in range(4):
    ax.plot([X[j] for X in paramsList], label='x{0}'.format(j))
ax.legend(loc=0)
ax.set_title('Parameter values')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(np.ravel(dataCoords[np.where(dataLabels == 0)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 0)])[1::2], ls='', marker='o')

ax.plot(np.ravel(dataCoords[np.where(dataLabels == 1)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 1)])[1::2], ls='', marker='o')

X = np.linspace(0, 1, num=20)
Z = np.zeros((len(X), len(X)))

# Contour map
for j in range(len(X)):
    for k in range(len(X)):
        # Fill Z with the labels (numerical values)
        # the inner loop goes over the columns of Z,
        # which corresponds to sweeping x-values
        # Therefore, the role of j,k is flipped in the signature
        Z[j, k] = predict_qubitF( np.array([X[k], X[j]]),currentParams,[0,1])
        
ax.contourf(X, X, Z, cmap='bwr', levels=30)

# %% [markdown]
# # 4.0

# %%
c = 1
a = 1
aparam=4.0*pi

# Do the updates
lossList = []
coeffsList = []
paramsList = []
accuracyList = []

np.random.seed(2)
currentParams = pi*np.random.uniform(size=8)
for j in range(50): 
    
    cj = c/(j+1)**(1/3)
    aj = a/(j+1)

    
    # Grab a subset of the data for minibatching
    #np.random.seed(j)
    np.random.seed(2)
    #data_ixs = np.random.choice(len(shuffled_data), size=len(shuffled_data))
    data_ixs = np.random.choice(len(data), size=100)
    
    # Evaluate the loss over that subset
    # We include a regularization term at the end 
    L = lambda x: np.sum([loss_qubitF(aparam*data[j][0],aparam*data[j][1],x,[0,1]) for j in data_ixs])/len(data_ixs) 
    
    lossList.append(L(currentParams))
    coeffsList.append((cj, aj))
    paramsList.append(currentParams)
    accuracyList.append(np.sum([predict_qubitF(data[j][0],currentParams,[0,1]) ==data[j][1] for j in data_ixs])/len(data_ixs))
    print(j,"th iteration L=",lossList[-1],"Accuracy =",accuracyList[-1])
    currentParams = SPSA_update(L, currentParams, aj, cj)

# %%
fig = plt.figure(figsize=(15, 10))

ax = fig.add_subplot(2, 2, 1)
ax.plot(lossList)
ax.set_title('Loss function\nStart {0} Finish {1}'.format(np.round(lossList[0], 3), np.round(lossList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 2)
ax.plot(accuracyList)
ax.set_title('Classification accuracy \nStart {0} Finish {1}'.format(np.round(accuracyList[0], 3), np.round(accuracyList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 3)
ax.plot([c[0] for c in coeffsList], label='a')
ax.plot([c[1] for c in coeffsList], label='c')
ax.legend(loc=0)
ax.set_title('Update coefficients')

ax = fig.add_subplot(2, 2, 4)
for j in range(4):
    ax.plot([X[j] for X in paramsList], label='x{0}'.format(j))
ax.legend(loc=0)
ax.set_title('Parameter values')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(np.ravel(dataCoords[np.where(dataLabels == 0)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 0)])[1::2], ls='', marker='o')

ax.plot(np.ravel(dataCoords[np.where(dataLabels == 1)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 1)])[1::2], ls='', marker='o')

X = np.linspace(0, 1, num=20)
Z = np.zeros((len(X), len(X)))

# Contour map
for j in range(len(X)):
    for k in range(len(X)):
        # Fill Z with the labels (numerical values)
        # the inner loop goes over the columns of Z,
        # which corresponds to sweeping x-values
        # Therefore, the role of j,k is flipped in the signature
        Z[j, k] = predict_qubitF( np.array([X[k], X[j]]),currentParams,[0,1])
        
ax.contourf(X, X, Z, cmap='bwr', levels=30)

# %% [markdown]
# # 8.0

# %%
c = 1
a = 1
aparam=8.0*pi

# Do the updates
lossList = []
coeffsList = []
paramsList = []
accuracyList = []

np.random.seed(2)
currentParams = pi*np.random.uniform(size=8)
for j in range(50):     
    
    cj = c/(j+1)**(1/3)
    aj = a/(j+1)

    
    # Grab a subset of the data for minibatching
    #np.random.seed(j)
    np.random.seed(2)
    #data_ixs = np.random.choice(len(shuffled_data), size=len(shuffled_data))
    data_ixs = np.random.choice(len(data), size=100)
    
    # Evaluate the loss over that subset
    # We include a regularization term at the end 
    L = lambda x: np.sum([loss_qubitF(aparam*data[j][0],aparam*data[j][1],x,[0,1]) for j in data_ixs])/len(data_ixs) 
    
    lossList.append(L(currentParams))
    coeffsList.append((cj, aj))
    paramsList.append(currentParams)
    accuracyList.append(np.sum([predict_qubitF(data[j][0],currentParams,[0,1]) ==data[j][1] for j in data_ixs])/len(data_ixs))
    print(j,"th iteration L=",lossList[-1],"Accuracy =",accuracyList[-1])
    currentParams = SPSA_update(L, currentParams, aj, cj)

# %%
fig = plt.figure(figsize=(15, 10))

ax = fig.add_subplot(2, 2, 1)
ax.plot(lossList)
ax.set_title('Loss function\nStart {0} Finish {1}'.format(np.round(lossList[0], 3), np.round(lossList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 2)
ax.plot(accuracyList)
ax.set_title('Classification accuracy \nStart {0} Finish {1}'.format(np.round(accuracyList[0], 3), np.round(accuracyList[-1], 3)))
ax.set_yscale('log')

ax = fig.add_subplot(2, 2, 3)
ax.plot([c[0] for c in coeffsList], label='a')
ax.plot([c[1] for c in coeffsList], label='c')
ax.legend(loc=0)
ax.set_title('Update coefficients')

ax = fig.add_subplot(2, 2, 4)
for j in range(4):
    ax.plot([X[j] for X in paramsList], label='x{0}'.format(j))
ax.legend(loc=0)
ax.set_title('Parameter values')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(np.ravel(dataCoords[np.where(dataLabels == 0)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 0)])[1::2], ls='', marker='o')

ax.plot(np.ravel(dataCoords[np.where(dataLabels == 1)])[::2],
np.ravel(dataCoords[np.where(dataLabels == 1)])[1::2], ls='', marker='o')

X = np.linspace(0, 1, num=20)
Z = np.zeros((len(X), len(X)))

# Contour map
for j in range(len(X)):
    for k in range(len(X)):
        # Fill Z with the labels (numerical values)
        # the inner loop goes over the columns of Z,
        # which corresponds to sweeping x-values
        # Therefore, the role of j,k is flipped in the signature
        Z[j, k] = predict_qubitF( np.array([X[k], X[j]]),currentParams,[0,1])
        
ax.contourf(X, X, Z, cmap='bwr', levels=30)
