# %% [markdown]
# # Dataset Generation
# I am following from the scikit-learn website and blog(machinelearningmastery.com) to generate the dataset

# %%
from random import seed
from random import random

from numpy import where
from collections import Counter
from sklearn.datasets import make_blobs
from matplotlib import pyplot

# %%
# define dataset
centers = [(0.35, 0.25), (0.65, 0.25)]

X, y = make_blobs(n_samples=1500, centers=centers,cluster_std=0.08, random_state=1)
# summarize dataset shape

X[:,1:] = X[:,1:] * 2
print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])
# plot the dataset and color the by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({1: 750, 0: 750})
# [0.59769404 0.55751377] 1
# [0.31604058 0.38295504] 0
# [0.53930571 0.36128717] 1
# [0.47499356 0.36067175] 0
# [0.34016878 0.35027689] 0
# [0.63997966 0.43392091] 1
# [0.61415106 0.4022728 ] 1
# [0.55678256 0.43193296] 1
# [0.65962001 0.63120318] 1
# [0.8035335  0.57646313] 1

# %%
# define dataset
centers = [(0.17, 0.25), (0.3, 0.5), (0.17, 0.75)]

X, y = make_blobs(n_samples=1500, centers=centers,cluster_std=0.05, random_state=1)
# summarize dataset shape

X[:,:1] = X[:,:1] * 2.2
y=y%2

print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])
# plot the dataset and color the by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({0: 1000, 1: 500})
# [0.3020793  0.76797305] 0
# [0.32730579 0.21342345] 0
# [0.22179535 0.70665224] 0
# [0.83186615 0.45645992] 1
# [0.36048208 0.20321153] 0
# [0.36022203 0.72935028] 0
# [0.3247077  0.71946025] 0
# [0.53182602 0.47872905] 1
# [0.38722752 0.791001  ] 0
# [0.58510856 0.77389473] 0

# %%
# define dataset
centers = [(0.17, 0.2), (0.3, 0.4), (0.17, 0.6),(0.3,0.8)]

X, y = make_blobs(n_samples=1500, centers=centers,cluster_std=0.05, random_state=1)
# summarize dataset shape

X[:,:1] = X[:,:1] * 2.2
y=y%2

print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])
# plot the dataset and color the by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({1: 750, 0: 750})
# [0.5880793  0.81797305] 1
# [0.32730579 0.16342345] 0
# [0.50779535 0.75665224] 1
# [0.83186615 0.35645992] 1
# [0.36048208 0.15321153] 0
# [0.64622203 0.77935028] 1
# [0.3247077  0.56946025] 0
# [0.24582602 0.57872905] 0
# [0.67322752 0.841001  ] 1
# [0.58510856 0.62389473] 0

# %%
# define dataset
centers = [(0.3, 0.3), (0.3, 0.7),(0.7,0.7), (0.7, 0.3)]

X, y = make_blobs(n_samples=1500, centers=centers,cluster_std=0.07, random_state=1)
# summarize dataset shape

y=y%2

print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])
# plot the dataset and color the by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({1: 750, 0: 750})
# [0.65423228 0.32516227] 1
# [0.2702855  0.24879283] 0
# [0.6031425  0.23931313] 1
# [0.40936937 0.63904389] 1
# [0.29139768 0.23449614] 0
# [0.6912322 0.2710904] 1
# [0.66863217 0.65724435] 0
# [0.61843474 0.67022067] 0
# [0.70841751 0.35740139] 1
# [0.83434181 0.73345262] 0

# %%
# define dataset
centers=[]
for i in range(3):
    for j in range(3):
        centers.append([0.25*i+0.25,0.25*j+0.25])
        
X, y = make_blobs(n_samples=1500, centers=centers,cluster_std=0.05, random_state=1)
# summarize dataset shape

y=y%2

print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])
# plot the dataset and color the by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({0: 833, 1: 667})
# [0.71730877 0.26797305] 0
# [0.22877536 0.46342345] 1
# [0.68081607 0.45665224] 1
# [0.57812098 0.20645992] 1
# [0.24385549 0.20321153] 0
# [0.74373729 0.47935028] 1
# [0.47759441 0.71946025] 1
# [0.4417391  0.72872905] 1
# [0.75601251 0.541001  ] 1
# [0.84595844 0.27389473] 0

# %%
# define dataset
centers=[]
for i in range(4):
    for j in range(3):
            centers.append([0.2*i+0.2,0.2*j+0.2])        
for j in range(4):
    centers.append([0.8-0.2*j,0.8])
            

X, y = make_blobs(n_samples=1500, centers=centers,cluster_std=0.04, random_state=1)
# summarize dataset shape

y=y%2

print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])
# plot the dataset and color the by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({0: 750, 1: 750})
# [0.77384702 0.81437844] 0
# [0.18302029 0.57073876] 0
# [0.74465286 0.76532179] 0
# [0.46249678 0.56516794] 1
# [0.19508439 0.16256922] 0
# [0.39498983 0.78348023] 0
# [0.78207553 0.3755682 ] 0
# [0.75339128 0.38298324] 0
# [0.60481001 0.8328008 ] 1
# [0.87676675 0.61911578] 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import mixture
from sklearn.neighbors import KernelDensity

# Generate 2D Gaussian data
N = 750
X, y = make_blobs(n_samples=N, centers=[(0.5,0.5)],cluster_std=0.04, random_state=1)

# Generate uniform noise

X_n = np.random.random((N,2))
y1=[1] * 750
y= np.concatenate((y, y1))

# Combine into a single data set
X = np.concatenate([X, X_n])

print(data.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])

counter = Counter(labels)

# Plot
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({0: 750, 1: 750})
# [0.54324372 0.56897567] 0
# [0.48282456 0.48101641] 0
# [0.52412144 0.51257728] 0
# [0.52111802 0.4375552 ] 0
# [0.49232658 0.46449484] 0
# [0.48302029 0.47073876] 0
# [0.54493649 0.51221068] 0
# [0.49253684 0.49772702] 0
# [0.42976297 0.52859158] 0
# [0.44710228 0.52411452] 0

# %%
N=1500
X = np.random.random((N,2))
y=[]
for i in range(N):
    if (X[i][0]-0.5)**2+(X[i][1]-0.5)**2<0.3**2 :
        y=np.concatenate((y,[0]))
    else:
        y=np.concatenate((y,[1]))
    
    
print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])

counter = Counter(labels)

# Plot
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({1.0: 1071, 0.0: 429})
# [0.18028057 0.84405949] 1.0
# [0.56063346 0.77174255] 0.0
# [0.9175005  0.54402091] 1.0
# [0.87711633 0.45098874] 1.0
# [0.79969964 0.3931228 ] 1.0
# [0.09019377 0.59443117] 1.0
# [0.90551845 0.68356245] 1.0
# [0.80655148 0.03793208] 1.0
# [0.74883564 0.42581472] 0.0
# [0.96559665 0.83326282] 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import mixture
from sklearn.neighbors import KernelDensity

# Generate 2D Gaussian data
N = 750
X, y = make_blobs(n_samples=N, centers=[(0.28,0.28),(0.78,0.78)],cluster_std=0.06, random_state=1)
y=[0] * 750
# Generate uniform noise

X_n = np.random.random((N,2))
y1=[1] * 750
y= np.concatenate((y, y1))

# Combine into a single data set
X = np.concatenate([X, X_n])

print(data.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])

counter = Counter(labels)

# Plot
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({0: 750, 1: 750})
# [0.84486558 0.8834635 ] 0
# [0.75423684 0.75152461] 0
# [0.81618215 0.79886592] 0
# [0.81167703 0.68633281] 0
# [0.26848987 0.22674226] 0
# [0.25453043 0.23610814] 0
# [0.34740473 0.29831602] 0
# [0.26880526 0.27659053] 0
# [0.17464446 0.32288738] 0
# [0.70065342 0.81617178] 0

# %%
N=1500
X = np.random.random((N,2))
y=[]
for i in range(N):
    if ((X[i][0]-0.28)**2+(X[i][1]-0.28)**2<0.15**2 or (X[i][0]-0.78)**2+(X[i][1]-0.78)**2<0.15**2) :
        y=np.concatenate((y,[0]))
    else:
        y=np.concatenate((y,[1]))
    
    
print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])

counter = Counter(labels)

# Plot
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({1.0: 1275, 0.0: 225})
# [0.88899581 0.41344347] 1.0
# [0.62537496 0.20097819] 1.0
# [0.55123394 0.39270936] 1.0
# [0.8287801  0.15327494] 1.0
# [0.54889111 0.81162143] 1.0
# [0.95974357 0.83689806] 1.0
# [0.65616151 0.59778838] 1.0
# [0.01370079 0.03600723] 1.0
# [0.9370819  0.37385048] 1.0
# [0.01003328 0.13386425] 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import mixture
from sklearn.neighbors import KernelDensity

# Generate 2D Gaussian data
N = 750
X, y = make_blobs(n_samples=N, centers=[(0.25,0.25),(0.75,0.75),(0.25,0.75),(0.75,0.25)],cluster_std=0.05, random_state=1)
y=[0] * 750
# Generate uniform noise

X_n = np.random.random((N,2))
y1=[1] * 750
y= np.concatenate((y, y1))

# Combine into a single data set
X = np.concatenate([X, X_n])

print(data.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])

counter = Counter(labels)

# Plot
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({0: 750, 1: 750})
# [0.80405465 0.33621959] 0
# [0.7285307  0.22627051] 0
# [0.7801518 0.2657216] 0
# [0.77639753 0.17194401] 0
# [0.24040822 0.20561855] 0
# [0.72877536 0.71342345] 0
# [0.30617061 0.26526335] 0
# [0.24067105 0.24715878] 0
# [0.66220372 0.78573948] 0
# [0.68387785 0.28014315] 0

# %%
N=1500
X = np.random.random((N,2))
y=[]
for i in range(N):
    if ((X[i][0]-0.25)**2+(X[i][1]-0.25)**2<0.15**2 or (X[i][0]-0.75)**2+(X[i][1]-0.75)**2<0.15**2 or
       (X[i][0]-0.75)**2+(X[i][1]-0.25)**2<0.15**2 or (X[i][0]-0.25)**2+(X[i][1]-0.75)**2<0.15**2) :
        y=np.concatenate((y,[0]))
    else:
        y=np.concatenate((y,[1]))
    
    
print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])

counter = Counter(y)

# Plot
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()
# Out:
# (1500, 2) (1500,)
# Counter({1.0: 1110, 0.0: 390})
# [0.57401921 0.91821702] 1.0
# [0.45092763 0.15733566] 1.0
# [0.70029578 0.72858341] 0.0
# [0.19257051 0.26528727] 0.0
# [0.26977822 0.44836587] 1.0
# [0.3455648  0.88007554] 1.0
# [0.20353254 0.68125547] 0.0
# [0.9460182  0.68676168] 1.0
# [0.14548092 0.49527602] 1.0
# [0.18813799 0.51370936] 1.0
