# %% [markdown]
# ## There is some problem with the previous code
# So I made modification

# %%
import random
from random import seed
from random import random

from numpy import where
from collections import Counter
from sklearn.datasets import make_blobs
from matplotlib import pyplot

import numpy as np
import matplotlib.pyplot as plt
from sklearn import mixture
from sklearn.neighbors import KernelDensity

# %%
def my_circle(center, rx, ry, Nmax):
    R = 1
    r2 = R * np.sqrt(np.random.rand(Nmax, 1))
    theta2 = 2 * np.pi * np.random.rand(Nmax, 1)
    x2 = rx*r2 * np.cos(theta2) + center[0]
    y2 = ry*r2 * np.sin(theta2) + center[1]
    return np.transpose([x2,y2])[0]

# %%
X1=my_circle([0.3,0.5],0.25,0.4,750)
X2=my_circle([0.7,0.5],0.25,0.4,750)
y1=[0] * 750
y2=[1] * 750

X_1=np.concatenate((X1,X2))
y_1=np.concatenate((y1, y2))

# Generate uniform noise
counter = Counter(y_1)


# Plot
for label, _ in counter.items():
	row_ix = where(y_1 == label)[0]
	pyplot.scatter(X_1[row_ix, 0], X_1[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()

# %%
X1=my_circle([0.4,0.2],0.25,0.15,375)
X2=my_circle([0.6,0.5],0.25,0.15,750)
X3=my_circle([0.4,0.8],0.25,0.15,375)
y1=[0] * 375
y2=[1] * 750
y3=[0] * 375

X_2=np.concatenate((X1,X2,X3))
y_2=np.concatenate((y1, y2,y3))

# Generate uniform noise
counter = Counter(y_2)

# Plot

for label, _ in counter.items():
	row_ix = where(y_2 == label)[0]
	pyplot.scatter(X_2[row_ix, 0], X_2[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()

# %%
X1=my_circle([0.3,0.2],0.25,0.12,375)
X2=my_circle([0.7,0.4],0.25,0.12,375)
X3=my_circle([0.3,0.6],0.25,0.12,375)
X4=my_circle([0.7,0.8],0.25,0.12,375)
y1=[0] * 375
y2=[1] * 375
y3=[0] * 375
y4=[1] * 375

X_3=np.concatenate((X1,X2,X3,X4))
y_3=np.concatenate((y1, y2,y3,y4))

# Generate uniform noise
counter = Counter(y_3)

# Plot

for label, _ in counter.items():
	row_ix = where(y_3 == label)[0]
	pyplot.scatter(X_3[row_ix, 0], X_3[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()

# %%
X1=my_circle([0.25,0.25],0.2,0.2,375)
X2=my_circle([0.25,0.75],0.2,0.2,375)
X3=my_circle([0.75,0.75],0.2,0.2,375)
X4=my_circle([0.75,0.25],0.2,0.2,375)
y1=[0] * 375
y2=[1] * 375
y3=[0] * 375
y4=[1] * 375

X_4=np.concatenate((X1,X2,X3,X4))
y_4=np.concatenate((y1, y2,y3,y4))

# Generate uniform noise
counter = Counter(y_4)

# Plot

for label, _ in counter.items():
	row_ix = where(y_4 == label)[0]
	pyplot.scatter(X_4[row_ix, 0], X_4[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()

# %%
r=0.12
n=166
X1=my_circle([0.2,0.2],r,r,n)
X2=my_circle([0.5,0.2],r,r,n)
X3=my_circle([0.8,0.2],r,r,n)
X4=my_circle([0.2,0.5],r,r,n)
X5=my_circle([0.5,0.5],r,r,n)
X6=my_circle([0.8,0.5],r,r,n)
X7=my_circle([0.2,0.8],r,r,n)
X8=my_circle([0.5,0.8],r,r,n)
X9=my_circle([0.8,0.8],r,r,n)

y1=[0] * n
y2=[1] * n
y3=[0] * n
y4=[1] * n
y5=[0] * n
y6=[1] * n
y7=[0] * n
y8=[1] * n
y9=[0] * n


X_5=np.concatenate((X1,X2,X3,X4,X5,X6,X7,X8,X9))
y_5=np.concatenate((y1, y2,y3,y4,y5,y6,y7,y8,y9))

# Generate uniform noise
counter = Counter(y_5)

# Plot

for label, _ in counter.items():
	row_ix = where(y_5 == label)[0]
	pyplot.scatter(X_5[row_ix, 0], X_5[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()

# %%
r=0.1
n=93
X1=my_circle([0.15,0.15],r,r,n)
X2=my_circle([0.38,0.15],r,r,n)
X3=my_circle([0.62,0.15],r,r,n)
X4=my_circle([0.85,0.15],r,r,n)
X5=my_circle([0.15,0.38],r,r,n)
X6=my_circle([0.38,0.38],r,r,n)
X7=my_circle([0.62,0.38],r,r,n)
X8=my_circle([0.85,0.38],r,r,n)
X9=my_circle([0.15,0.62],r,r,n)
X10=my_circle([0.38,0.62],r,r,n)
X11=my_circle([0.62,0.62],r,r,n)
X12=my_circle([0.85,0.62],r,r,n)
X13=my_circle([0.15,0.85],r,r,n)
X14=my_circle([0.38,0.85],r,r,n)
X15=my_circle([0.62,0.85],r,r,n)
X16=my_circle([0.85,0.85],r,r,n)

y1=[0] * n
y2=[1] * n
y3=[0] * n
y4=[1] * n

y5=[1] * n
y6=[0] * n
y7=[1] * n
y8=[0] * n
y9=[0] * n
y10=[1] * n
y11=[0] * n
y12=[1] * n
y13=[1] * n
y14=[0] * n
y15=[1] * n
y16=[0] * n

X_6=np.concatenate((X1,X2,X3,X4,X5,X6,X7,X8,X9,X10,X11,X12,X13,X14,X15,X16))
y_6=np.concatenate((y1, y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13,y14,y15,y16))

# Generate uniform noise
counter = Counter(y_6)

# Plot
for label, _ in counter.items():
	row_ix = where(y_6 == label)[0]
	pyplot.scatter(X_6[row_ix, 0], X_6[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()

# %%
# I have to ask how to generate the datapoints
#Reference https://stackoverflow.com/questions/66561407/random-numer-generation-except-inside-of-the-circle-in-python/66562232#66562232


X1 = []
radius = 0.25
n=750

index = 0
while index < n:
  x=random.random()
  y=random.random()
  if (x-0.5)**2 + (y-0.5)**2 > radius**2:
    X1 = X1 + [[x,y]]
    index = index + 1
    
y1=[1] *750

X2=my_circle([0.5,0.5],radius,radius,750)

y2=[0] *750

X_7=np.concatenate((X1,X2))
y_7=np.concatenate((y1, y2))

# Generate uniform noise
counter = Counter(y_7)

# Plot

for label, _ in counter.items():
	row_ix = where(y_7 == label)[0]
	pyplot.scatter(X_7[row_ix, 0], X_7[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()

# %%
X1 = []
radius = 0.15
n=750

index = 0
while index < n:
  x=random.random()
  y=random.random()
  if ((x-0.25)**2 + (y-0.25)**2 > radius**2 and (x-0.75)**2 + (y-0.75)**2 > radius**2):
    X1 = X1 + [[x,y]]
    index = index + 1
    
y1=[1] *750

X2=my_circle([0.25,0.25],radius,radius,375)
X3=my_circle([0.75,0.75],radius,radius,375)

y2=[0] *750

X_8=np.concatenate((X1,X2,X3))
y_8=np.concatenate((y1, y2))

# Generate uniform noise
counter = Counter(y_8)

# Plot

for label, _ in counter.items():
	row_ix = where(y_8 == label)[0]
	pyplot.scatter(X_8[row_ix, 0], X_8[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()

# %%
import random
X1 = []
radius = 0.15
n=750
n2=187
index = 0
while index < n:
  x=random.random()
  y=random.random()
  if ((x-0.25)**2 + (y-0.25)**2 > radius**2 and (x-0.75)**2 + (y-0.75)**2 > radius**2 and 
     (x-0.75)**2 + (y-0.25)**2 > radius**2 and (x-0.25)**2 + (y-0.75)**2 > radius**2 ):
    X1 = X1 + [[x,y]]
    index = index + 1
    
y1=[1] *750

X2=my_circle([0.25,0.25],radius,radius,n2)
X3=my_circle([0.75,0.75],radius,radius,n2)
X4=my_circle([0.75,0.25],radius,radius,n2)
X5=my_circle([0.25,0.75],radius,radius,n2)

y2=[0] *748

X_9=np.concatenate((X1,X2,X3,X4,X5))
y_9=np.concatenate((y1, y2))

# Generate uniform noise
counter = Counter(y_9)

# Plot
for label, _ in counter.items():
	row_ix = where(y_9 == label)[0]
	pyplot.scatter(X_9[row_ix, 0], X_9[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
pyplot.show()

# %%
pyplot.subplot(3, 3, 1)
# Plot
for label, _ in counter.items():
	row_ix = where(y_1 == label)[0]
	pyplot.scatter(X_1[row_ix, 0], X_1[row_ix, 1], label=str(label))
pyplot.legend()

pyplot.xlim([0, 1])
pyplot.ylim([0, 1])


pyplot.subplot(3, 3, 2)
for label, _ in counter.items():
	row_ix = where(y_2 == label)[0]
	pyplot.scatter(X_2[row_ix, 0], X_2[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])




pyplot.subplot(3, 3, 3)
for label, _ in counter.items():
	row_ix = where(y_3 == label)[0]
	pyplot.scatter(X_3[row_ix, 0], X_3[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])


pyplot.subplot(3, 3, 4)
for label, _ in counter.items():
	row_ix = where(y_4 == label)[0]
	pyplot.scatter(X_4[row_ix, 0], X_4[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])



pyplot.subplot(3, 3, 5)
for label, _ in counter.items():
	row_ix = where(y_5 == label)[0]
	pyplot.scatter(X_5[row_ix, 0], X_5[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])


plt.subplot(3, 3, 6)
for label, _ in counter.items():
	row_ix = where(y_6 == label)[0]
	pyplot.scatter(X_6[row_ix, 0], X_6[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])


pyplot.subplot(3, 3, 7)
for label, _ in counter.items():
	row_ix = where(y_7 == label)[0]
	pyplot.scatter(X_7[row_ix, 0], X_7[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])


pyplot.subplot(3, 3, 8)
for label, _ in counter.items():
	row_ix = where(y_8 == label)[0]
	pyplot.scatter(X_8[row_ix, 0], X_8[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])


pyplot.subplot(3, 3, 9)
for label, _ in counter.items():
	row_ix = where(y_9 == label)[0]
	pyplot.scatter(X_9[row_ix, 0], X_9[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.xlim([0, 1])
pyplot.ylim([0, 1])
# Out:
# (0.0, 1.0)
